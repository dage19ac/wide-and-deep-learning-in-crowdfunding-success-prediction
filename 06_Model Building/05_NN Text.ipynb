# %% [markdown]
# #### Setup

# %%
# !pip install -U tensorflow keras

# %%
# !pip install -U talos

# %%
# !pip install -U fasttext

# %%
# Import general Python libraries
import pandas as pd
import numpy as np
import random
import sklearn
import seaborn as sns
import os
import io
import matplotlib.pyplot as plt
from tqdm import tqdm
tqdm.pandas()

# %%
# Specify seeds for random-operations
seed_value = 0
os.environ['PYTHONHASHSEED']=str(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)

# %%
# Import sklearn-specific modules
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
# Import tensorflow-specific modules
import tensorflow as tf
tf.random.set_seed(seed_value)
print("Tensorflow Version: {}".format(tf.__version__))
print("Keras Version: {}".format(tf.keras.__version__))
# Out:
# Tensorflow Version: 2.4.1
# Keras Version: 2.4.0

# %%
# Import keras-specific modules
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dropout, BatchNormalization, LayerNormalization, GaussianNoise, Activation
from tensorflow.keras.layers import Dense, Flatten, Embedding, Conv1D, MaxPool1D, AvgPool1D, GlobalMaxPool1D, GlobalAvgPool1D, RNN, GRU, LSTM, SeparableConv1D, SimpleRNN, Bidirectional, LocallyConnected1D, LeakyReLU, Input
from tensorflow.keras.optimizers import Adadelta, RMSprop, Adam, Adamax, Nadam
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.initializers import GlorotNormal, GlorotUniform, LecunNormal, LecunUniform, HeNormal, HeUniform, Constant
from tensorflow.keras.metrics import AUC, Precision, Recall
from tensorflow.keras.utils import plot_model
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences

# %%
# Import talos-specific modules
import talos

# %%
# Set pandas options
pd.set_option("display.max_columns", None)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set up TPU configurations
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.TPUStrategy(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.52.181.106:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.52.181.106:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU')]

# %% [markdown]
# #### Import Dataset:

# %%
# Import Kickstarter Dataset
kickstarter_df = pd.read_csv("04_Final Datasets/Kickstarter_Text.csv", index_col=0)
print(kickstarter_df.shape)
print(len(kickstarter_df.index.unique()))
kickstarter_df.head(1)
# Out:
# (246891, 7)
# 246891
#           campaign_successful                                        title  \
# 22821161                    0  sentio golf putters. feel is the difference
#
#                                                       blurb  \
# 22821161  choose the feel you want with our patented flo...
#
#                                                       story  \
# 22821161   sentio putters feature a unique floating face...
#
#                                                       risks  \
# 22821161  high tech process although we have made severa...
#
#                                          reward_description  \
# 22821161  our eternal gratitude. every little bit helps ...
#
#                                                 creator_bio
# 22821161  sentio golf is driven to produce the most adva...

# %%
# Import Word Embeddings
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')  # English
ft = fasttext.load_model('cc.en.300.bin')
print(ft.get_dimension())
# Out:
# Downloading https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
# 300
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# #### a) Baseline

# %% [markdown]
# This model provides the baseline, which will be used as starting point for the hyperparameter search. The goal is to gradually improve the model performance.
#
# **Hyperparameters:**
# - Preprocessing: Only Story, Removed Stopwords, Max_Features = No Restrictions, Max_Len = 500, Embedding_Dim = 300, Fasttext Embeddings
# - CNN: 2 Conv Layers (64 Filters, Window Size 7, ReLU, padding=same), MaxPooling (Size 5), GlobalMaxPooling, Dropout before Dense Classifier (Rate = 0.5), 1 Hidden Dense Layer (32 Units, ReLU), Nadam, Batch Size 512
# - RNN: 1 LSTM Layer (32 Units), RMSProp, Batch Size 512

# %% [markdown]
# ##### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["story"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()
# Out:
# 100%|██████████| 246891/246891 [00:23<00:00, 10588.88it/s]

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
# Define parameters for text processing 
max_features = 471366
max_len = 500
embedding_dim = 300

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(tokenizer.num_words))
# Out:
# Included Token: 471366

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      243.835115
# std       248.457559
# min         0.000000
# 25%        90.000000
# 50%       167.000000
# 75%       310.000000
# max      3555.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 500)
# Shape of X_val: (37034, 500)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (471366, 300)
# Number of Null Word Embeddings: 152

# %% [markdown]
# ##### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 500, 300)          141409800
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 64)           134464
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 100, 64)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 100, 64)           28736
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 141,575,113
# Trainable params: 165,313
# Non-trainable params: 141,409,800
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 21s 45ms/step - loss: 0.5949 - binary_accuracy: 0.6845 - val_loss: 0.5221 - val_binary_accuracy: 0.7383
# Epoch 2/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.5273 - binary_accuracy: 0.7360 - val_loss: 0.5415 - val_binary_accuracy: 0.7265
# Epoch 3/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.5062 - binary_accuracy: 0.7529 - val_loss: 0.5043 - val_binary_accuracy: 0.7510
# Epoch 4/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4917 - binary_accuracy: 0.7615 - val_loss: 0.4980 - val_binary_accuracy: 0.7540
# Epoch 5/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4779 - binary_accuracy: 0.7707 - val_loss: 0.4970 - val_binary_accuracy: 0.7538
# Epoch 6/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4593 - binary_accuracy: 0.7822 - val_loss: 0.5066 - val_binary_accuracy: 0.7559
# Epoch 7/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4419 - binary_accuracy: 0.7914 - val_loss: 0.5103 - val_binary_accuracy: 0.7564
# Epoch 8/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4236 - binary_accuracy: 0.8032 - val_loss: 0.5180 - val_binary_accuracy: 0.7539
# Epoch 9/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4028 - binary_accuracy: 0.8153 - val_loss: 0.5403 - val_binary_accuracy: 0.7511
# Epoch 10/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.3828 - binary_accuracy: 0.8258 - val_loss: 0.5464 - val_binary_accuracy: 0.7507
# Epoch 11/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.3623 - binary_accuracy: 0.8382 - val_loss: 0.5687 - val_binary_accuracy: 0.7461
# Epoch 12/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.3450 - binary_accuracy: 0.8470 - val_loss: 0.5786 - val_binary_accuracy: 0.7443
# Training Accuracy: 0.818
# Validation Accuracy: 0.756

# %% [markdown]
# ##### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 500, 300)          141409800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                42624
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 141,452,457
# Trainable params: 42,657
# Non-trainable params: 141,409,800
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 25s 63ms/step - loss: 0.6033 - binary_accuracy: 0.6736 - val_loss: 0.5529 - val_binary_accuracy: 0.7200
# Epoch 2/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5540 - binary_accuracy: 0.7201 - val_loss: 0.5553 - val_binary_accuracy: 0.7088
# Epoch 3/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5444 - binary_accuracy: 0.7287 - val_loss: 0.5326 - val_binary_accuracy: 0.7336
# Epoch 4/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5425 - binary_accuracy: 0.7273 - val_loss: 0.5280 - val_binary_accuracy: 0.7367
# Epoch 5/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5361 - binary_accuracy: 0.7318 - val_loss: 0.5251 - val_binary_accuracy: 0.7383
# Epoch 6/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5345 - binary_accuracy: 0.7338 - val_loss: 0.5233 - val_binary_accuracy: 0.7416
# Epoch 7/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5284 - binary_accuracy: 0.7373 - val_loss: 0.5367 - val_binary_accuracy: 0.7390
# Epoch 8/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5259 - binary_accuracy: 0.7376 - val_loss: 0.5257 - val_binary_accuracy: 0.7279
# Epoch 9/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5192 - binary_accuracy: 0.7428 - val_loss: 0.5242 - val_binary_accuracy: 0.7354
# Epoch 10/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5179 - binary_accuracy: 0.7424 - val_loss: 0.5258 - val_binary_accuracy: 0.7334
# Epoch 11/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.5129 - binary_accuracy: 0.7464 - val_loss: 0.5150 - val_binary_accuracy: 0.7480
# Epoch 12/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.5112 - binary_accuracy: 0.7484 - val_loss: 0.5233 - val_binary_accuracy: 0.7308
# Epoch 13/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5079 - binary_accuracy: 0.7503 - val_loss: 0.5097 - val_binary_accuracy: 0.7482
# Epoch 14/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5071 - binary_accuracy: 0.7486 - val_loss: 0.5295 - val_binary_accuracy: 0.7297
# Epoch 15/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5054 - binary_accuracy: 0.7515 - val_loss: 0.5100 - val_binary_accuracy: 0.7501
# Epoch 16/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5067 - binary_accuracy: 0.7491 - val_loss: 0.5053 - val_binary_accuracy: 0.7521
# Epoch 17/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5011 - binary_accuracy: 0.7522 - val_loss: 0.5193 - val_binary_accuracy: 0.7499
# Epoch 18/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5003 - binary_accuracy: 0.7548 - val_loss: 0.5141 - val_binary_accuracy: 0.7435
# Epoch 19/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4985 - binary_accuracy: 0.7552 - val_loss: 0.5224 - val_binary_accuracy: 0.7446
# Epoch 20/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4948 - binary_accuracy: 0.7589 - val_loss: 0.5017 - val_binary_accuracy: 0.7533
# Epoch 21/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4932 - binary_accuracy: 0.7592 - val_loss: 0.5014 - val_binary_accuracy: 0.7526
# Epoch 22/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4924 - binary_accuracy: 0.7588 - val_loss: 0.5050 - val_binary_accuracy: 0.7491
# Epoch 23/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4886 - binary_accuracy: 0.7609 - val_loss: 0.5024 - val_binary_accuracy: 0.7501
# Epoch 24/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4886 - binary_accuracy: 0.7620 - val_loss: 0.5000 - val_binary_accuracy: 0.7543
# Epoch 25/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4855 - binary_accuracy: 0.7631 - val_loss: 0.5042 - val_binary_accuracy: 0.7485
# Epoch 26/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4873 - binary_accuracy: 0.7618 - val_loss: 0.4995 - val_binary_accuracy: 0.7565
# Epoch 27/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4856 - binary_accuracy: 0.7644 - val_loss: 0.4973 - val_binary_accuracy: 0.7551
# Epoch 28/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4838 - binary_accuracy: 0.7655 - val_loss: 0.4957 - val_binary_accuracy: 0.7576
# Epoch 29/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4849 - binary_accuracy: 0.7638 - val_loss: 0.5038 - val_binary_accuracy: 0.7510
# Epoch 30/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4815 - binary_accuracy: 0.7671 - val_loss: 0.4984 - val_binary_accuracy: 0.7570
# Epoch 31/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4820 - binary_accuracy: 0.7643 - val_loss: 0.5102 - val_binary_accuracy: 0.7505
# Epoch 32/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4788 - binary_accuracy: 0.7662 - val_loss: 0.4983 - val_binary_accuracy: 0.7567
# Epoch 33/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4749 - binary_accuracy: 0.7713 - val_loss: 0.4972 - val_binary_accuracy: 0.7546
# Training Accuracy: 0.769
# Validation Accuracy: 0.758

# %% [markdown]
# #### b) Test Different Preprocessing Strategies

# %% [markdown]
# ##### Check How Different Paddings Affect Model Performance:

# %% [markdown]
# ###### Data Preparation:

# %%
# Define parameters for text processing 
max_features = 471366
max_len = 500
embedding_dim = 300

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(max_features))
# Out:
# Included Token: 471366

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      243.835115
# std       248.457559
# min         0.000000
# 25%        90.000000
# 50%       167.000000
# 75%       310.000000
# max      3555.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="post", truncating="pre")
X_val = pad_sequences(X_val, maxlen=max_len, padding="post", truncating="pre")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 500)
# Shape of X_val: (37034, 500)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (471366, 300)
# Number of Null Word Embeddings: 152

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 500, 300)          141409800
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 500, 64)           134464
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 100, 64)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 100, 64)           28736
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 141,575,113
# Trainable params: 165,313
# Non-trainable params: 141,409,800
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 21s 45ms/step - loss: 0.5937 - binary_accuracy: 0.6854 - val_loss: 0.5255 - val_binary_accuracy: 0.7361
# Epoch 2/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.5283 - binary_accuracy: 0.7355 - val_loss: 0.5574 - val_binary_accuracy: 0.7134
# Epoch 3/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.5102 - binary_accuracy: 0.7482 - val_loss: 0.5045 - val_binary_accuracy: 0.7507
# Epoch 4/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4930 - binary_accuracy: 0.7602 - val_loss: 0.4985 - val_binary_accuracy: 0.7547
# Epoch 5/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4806 - binary_accuracy: 0.7692 - val_loss: 0.5001 - val_binary_accuracy: 0.7524
# Epoch 6/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4616 - binary_accuracy: 0.7792 - val_loss: 0.5052 - val_binary_accuracy: 0.7573
# Epoch 7/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4456 - binary_accuracy: 0.7887 - val_loss: 0.5190 - val_binary_accuracy: 0.7510
# Epoch 8/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4244 - binary_accuracy: 0.8017 - val_loss: 0.5161 - val_binary_accuracy: 0.7506
# Epoch 9/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4019 - binary_accuracy: 0.8144 - val_loss: 0.5456 - val_binary_accuracy: 0.7499
# Epoch 10/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.3860 - binary_accuracy: 0.8237 - val_loss: 0.5704 - val_binary_accuracy: 0.7466
# Epoch 11/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.3623 - binary_accuracy: 0.8363 - val_loss: 0.5687 - val_binary_accuracy: 0.7416
# Training Accuracy: 0.805
# Validation Accuracy: 0.757

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 500, 300)          141409800
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 32)                42624
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 141,452,457
# Trainable params: 42,657
# Non-trainable params: 141,409,800
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 25s 62ms/step - loss: 0.6466 - binary_accuracy: 0.6520 - val_loss: 0.6101 - val_binary_accuracy: 0.6699
# Epoch 2/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.6222 - binary_accuracy: 0.6447 - val_loss: 0.6378 - val_binary_accuracy: 0.6518
# Epoch 3/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.6381 - binary_accuracy: 0.6550 - val_loss: 0.6219 - val_binary_accuracy: 0.6570
# Epoch 4/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.6331 - binary_accuracy: 0.6551 - val_loss: 0.7177 - val_binary_accuracy: 0.6576
# Epoch 5/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.6287 - binary_accuracy: 0.6560 - val_loss: 0.6174 - val_binary_accuracy: 0.6574
# Epoch 6/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.6196 - binary_accuracy: 0.6576 - val_loss: 0.6119 - val_binary_accuracy: 0.6442
# Training Accuracy: 0.670
# Validation Accuracy: 0.670

# %% [markdown]
# ###### Result:

# %% [markdown]
# Padding / Truncating:
# - Pre/Pre: CNN = 80.6% vs. 75.7%; RNN = 76.4% vs. 75.6%
# - Post/Post: CNN = 80.6% vs. 75.5%; 68.1% vs. 67.8%
# - Pre/Post: CNN = 81.8% vs. 75.6%; RNN = 76.9% vs. 75.8%
# - Post/Pre: CNN = 80.5% vs. 75.7%; RNN = 67% vs. 67%

# %% [markdown]
# Conclusion:
# - RNN was not able to learn when padding="post" (probably because short sentences are processed sequentially and at the end many null-embeddings are considered)
# - CNN was relatively unaffected, as it just searches for local cues
# - Padding="pre" & Truncating="post" provided the best results

# %% [markdown]
# ##### Check how different embedding dimensions affect model performance:

# %% [markdown]
# ###### Data Preparation:

# %%
# Reduce embedding dimension
print("Before: {}".format(ft.get_dimension()))
fasttext.util.reduce_model(ft, 200)
print("After: {}".format(ft.get_dimension()))
# Out:
# Before: 300
# After: 200

# %%
# Define parameters for text processing 
max_features = 471366
max_len = 500
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(max_features))
# Out:
# Included Token: 471366

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      243.835115
# std       248.457559
# min         0.000000
# 25%        90.000000
# 50%       167.000000
# 75%       310.000000
# max      3555.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 500)
# Shape of X_val: (37034, 500)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (471366, 200)
# Number of Null Word Embeddings: 152

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, 500, 200)          94273200
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 500, 64)           89664
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 100, 64)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 100, 64)           28736
# _________________________________________________________________
# global_max_pooling1d_7 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 94,393,713
# Trainable params: 120,513
# Non-trainable params: 94,273,200
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 22s 51ms/step - loss: 0.6044 - binary_accuracy: 0.6743 - val_loss: 0.5361 - val_binary_accuracy: 0.7309
# Epoch 2/100
# 338/338 [==============================] - 14s 41ms/step - loss: 0.5444 - binary_accuracy: 0.7231 - val_loss: 0.5508 - val_binary_accuracy: 0.7082
# Epoch 3/100
# 338/338 [==============================] - 31s 92ms/step - loss: 0.5262 - binary_accuracy: 0.7356 - val_loss: 0.5151 - val_binary_accuracy: 0.7460
# Epoch 4/100
# 338/338 [==============================] - 9s 26ms/step - loss: 0.5144 - binary_accuracy: 0.7444 - val_loss: 0.5129 - val_binary_accuracy: 0.7427
# Epoch 5/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5041 - binary_accuracy: 0.7526 - val_loss: 0.5061 - val_binary_accuracy: 0.7488
# Epoch 6/100
# 338/338 [==============================] - 9s 26ms/step - loss: 0.4931 - binary_accuracy: 0.7583 - val_loss: 0.5077 - val_binary_accuracy: 0.7477
# Epoch 7/100
# 338/338 [==============================] - 9s 26ms/step - loss: 0.4832 - binary_accuracy: 0.7650 - val_loss: 0.5215 - val_binary_accuracy: 0.7360
# Epoch 8/100
# 338/338 [==============================] - 9s 26ms/step - loss: 0.4711 - binary_accuracy: 0.7741 - val_loss: 0.5444 - val_binary_accuracy: 0.7281
# Epoch 9/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4589 - binary_accuracy: 0.7802 - val_loss: 0.5574 - val_binary_accuracy: 0.7191
# Epoch 10/100
# 338/338 [==============================] - 9s 26ms/step - loss: 0.4479 - binary_accuracy: 0.7880 - val_loss: 0.5342 - val_binary_accuracy: 0.7412
# Epoch 11/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4380 - binary_accuracy: 0.7942 - val_loss: 0.5263 - val_binary_accuracy: 0.7474
# Epoch 12/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4273 - binary_accuracy: 0.7990 - val_loss: 0.5598 - val_binary_accuracy: 0.7423
# Training Accuracy: 0.774
# Validation Accuracy: 0.749

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 500, 200)          94273200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                29824
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 94,303,057
# Trainable params: 29,857
# Non-trainable params: 94,273,200
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 30s 78ms/step - loss: 0.6120 - binary_accuracy: 0.6698 - val_loss: 0.5548 - val_binary_accuracy: 0.7127
# Epoch 2/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5592 - binary_accuracy: 0.7139 - val_loss: 0.5617 - val_binary_accuracy: 0.7174
# Epoch 3/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5520 - binary_accuracy: 0.7216 - val_loss: 0.5391 - val_binary_accuracy: 0.7275
# Epoch 4/100
# 338/338 [==============================] - 15s 45ms/step - loss: 0.5492 - binary_accuracy: 0.7218 - val_loss: 0.5355 - val_binary_accuracy: 0.7304
# Epoch 5/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5442 - binary_accuracy: 0.7250 - val_loss: 0.5410 - val_binary_accuracy: 0.7229
# Epoch 6/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5408 - binary_accuracy: 0.7242 - val_loss: 0.5371 - val_binary_accuracy: 0.7310
# Epoch 7/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5381 - binary_accuracy: 0.7272 - val_loss: 0.5306 - val_binary_accuracy: 0.7303
# Epoch 8/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5362 - binary_accuracy: 0.7280 - val_loss: 0.5269 - val_binary_accuracy: 0.7319
# Epoch 9/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5298 - binary_accuracy: 0.7345 - val_loss: 0.5316 - val_binary_accuracy: 0.7281
# Epoch 10/100
# 338/338 [==============================] - 22s 64ms/step - loss: 0.5303 - binary_accuracy: 0.7325 - val_loss: 0.5230 - val_binary_accuracy: 0.7392
# Epoch 11/100
# 338/338 [==============================] - 26s 77ms/step - loss: 0.5261 - binary_accuracy: 0.7345 - val_loss: 0.5251 - val_binary_accuracy: 0.7401
# Epoch 12/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5262 - binary_accuracy: 0.7371 - val_loss: 0.5216 - val_binary_accuracy: 0.7383
# Epoch 13/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5211 - binary_accuracy: 0.7402 - val_loss: 0.5190 - val_binary_accuracy: 0.7396
# Epoch 14/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5188 - binary_accuracy: 0.7392 - val_loss: 0.5467 - val_binary_accuracy: 0.7326
# Epoch 15/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5204 - binary_accuracy: 0.7405 - val_loss: 0.5213 - val_binary_accuracy: 0.7433
# Epoch 16/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5185 - binary_accuracy: 0.7419 - val_loss: 0.5147 - val_binary_accuracy: 0.7450
# Epoch 17/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5174 - binary_accuracy: 0.7431 - val_loss: 0.5242 - val_binary_accuracy: 0.7291
# Epoch 18/100
# 338/338 [==============================] - 15s 46ms/step - loss: 0.5146 - binary_accuracy: 0.7439 - val_loss: 0.5176 - val_binary_accuracy: 0.7433
# Epoch 19/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5163 - binary_accuracy: 0.7414 - val_loss: 0.5159 - val_binary_accuracy: 0.7466
# Epoch 20/100
# 338/338 [==============================] - 40s 119ms/step - loss: 0.5099 - binary_accuracy: 0.7480 - val_loss: 0.5133 - val_binary_accuracy: 0.7441
# Epoch 21/100
# 338/338 [==============================] - 23s 67ms/step - loss: 0.5099 - binary_accuracy: 0.7476 - val_loss: 0.5146 - val_binary_accuracy: 0.7424
# Epoch 22/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5084 - binary_accuracy: 0.7479 - val_loss: 0.5167 - val_binary_accuracy: 0.7369
# Epoch 23/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5038 - binary_accuracy: 0.7511 - val_loss: 0.5238 - val_binary_accuracy: 0.7305
# Epoch 24/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.5068 - binary_accuracy: 0.7482 - val_loss: 0.5133 - val_binary_accuracy: 0.7478
# Epoch 25/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5034 - binary_accuracy: 0.7501 - val_loss: 0.5244 - val_binary_accuracy: 0.7281
# Epoch 26/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5035 - binary_accuracy: 0.7516 - val_loss: 0.5156 - val_binary_accuracy: 0.7450
# Epoch 27/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.5044 - binary_accuracy: 0.7527 - val_loss: 0.5062 - val_binary_accuracy: 0.7510
# Epoch 28/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5035 - binary_accuracy: 0.7518 - val_loss: 0.5083 - val_binary_accuracy: 0.7502
# Epoch 29/100
# 338/338 [==============================] - 27s 79ms/step - loss: 0.5035 - binary_accuracy: 0.7512 - val_loss: 0.5028 - val_binary_accuracy: 0.7540
# Epoch 30/100
# 338/338 [==============================] - 31s 91ms/step - loss: 0.5016 - binary_accuracy: 0.7515 - val_loss: 0.5047 - val_binary_accuracy: 0.7539
# Epoch 31/100
# 338/338 [==============================] - 17s 51ms/step - loss: 0.5005 - binary_accuracy: 0.7527 - val_loss: 0.5039 - val_binary_accuracy: 0.7537
# Epoch 32/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4979 - binary_accuracy: 0.7548 - val_loss: 0.5086 - val_binary_accuracy: 0.7495
# Epoch 33/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4951 - binary_accuracy: 0.7576 - val_loss: 0.5008 - val_binary_accuracy: 0.7534
# Epoch 34/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4951 - binary_accuracy: 0.7566 - val_loss: 0.5016 - val_binary_accuracy: 0.7544
# Epoch 35/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4943 - binary_accuracy: 0.7583 - val_loss: 0.5065 - val_binary_accuracy: 0.7460
# Epoch 36/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4935 - binary_accuracy: 0.7578 - val_loss: 0.4985 - val_binary_accuracy: 0.7558
# Epoch 37/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4929 - binary_accuracy: 0.7570 - val_loss: 0.5189 - val_binary_accuracy: 0.7422
# Epoch 38/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4895 - binary_accuracy: 0.7600 - val_loss: 0.5006 - val_binary_accuracy: 0.7548
# Epoch 39/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4920 - binary_accuracy: 0.7576 - val_loss: 0.5040 - val_binary_accuracy: 0.7481
# Epoch 40/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4999 - binary_accuracy: 0.7568 - val_loss: 0.4997 - val_binary_accuracy: 0.7568
# Epoch 41/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4908 - binary_accuracy: 0.7605 - val_loss: 0.4972 - val_binary_accuracy: 0.7569
# Epoch 42/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4858 - binary_accuracy: 0.7618 - val_loss: 0.4979 - val_binary_accuracy: 0.7558
# Epoch 43/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4868 - binary_accuracy: 0.7612 - val_loss: 0.4965 - val_binary_accuracy: 0.7569
# Epoch 44/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4846 - binary_accuracy: 0.7637 - val_loss: 0.4996 - val_binary_accuracy: 0.7517
# Epoch 45/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4833 - binary_accuracy: 0.7656 - val_loss: 0.5090 - val_binary_accuracy: 0.7530
# Epoch 46/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4857 - binary_accuracy: 0.7634 - val_loss: 0.5151 - val_binary_accuracy: 0.7585
# Epoch 47/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4829 - binary_accuracy: 0.7648 - val_loss: 0.5120 - val_binary_accuracy: 0.7510
# Epoch 48/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4808 - binary_accuracy: 0.7658 - val_loss: 0.5034 - val_binary_accuracy: 0.7563
# Epoch 49/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4816 - binary_accuracy: 0.7657 - val_loss: 0.4949 - val_binary_accuracy: 0.7570
# Epoch 50/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4810 - binary_accuracy: 0.7656 - val_loss: 0.5115 - val_binary_accuracy: 0.7563
# Epoch 51/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4800 - binary_accuracy: 0.7662 - val_loss: 0.4948 - val_binary_accuracy: 0.7592
# Epoch 52/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4782 - binary_accuracy: 0.7682 - val_loss: 0.5052 - val_binary_accuracy: 0.7496
# Epoch 53/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4788 - binary_accuracy: 0.7668 - val_loss: 0.5075 - val_binary_accuracy: 0.7556
# Epoch 54/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4752 - binary_accuracy: 0.7693 - val_loss: 0.4954 - val_binary_accuracy: 0.7555
# Epoch 55/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4778 - binary_accuracy: 0.7678 - val_loss: 0.4956 - val_binary_accuracy: 0.7557
# Epoch 56/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4771 - binary_accuracy: 0.7696 - val_loss: 0.4945 - val_binary_accuracy: 0.7593
# Epoch 57/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4739 - binary_accuracy: 0.7690 - val_loss: 0.5066 - val_binary_accuracy: 0.7595
# Epoch 58/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4744 - binary_accuracy: 0.7699 - val_loss: 0.4988 - val_binary_accuracy: 0.7579
# Epoch 59/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4729 - binary_accuracy: 0.7709 - val_loss: 0.4947 - val_binary_accuracy: 0.7563
# Epoch 60/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4733 - binary_accuracy: 0.7705 - val_loss: 0.4955 - val_binary_accuracy: 0.7613
# Epoch 61/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4730 - binary_accuracy: 0.7701 - val_loss: 0.5365 - val_binary_accuracy: 0.7318
# Epoch 62/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4710 - binary_accuracy: 0.7726 - val_loss: 0.4980 - val_binary_accuracy: 0.7608
# Epoch 63/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4693 - binary_accuracy: 0.7727 - val_loss: 0.4936 - val_binary_accuracy: 0.7594
# Epoch 64/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4700 - binary_accuracy: 0.7727 - val_loss: 0.4914 - val_binary_accuracy: 0.7598
# Epoch 65/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4696 - binary_accuracy: 0.7727 - val_loss: 0.4917 - val_binary_accuracy: 0.7616
# Epoch 66/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4680 - binary_accuracy: 0.7745 - val_loss: 0.4914 - val_binary_accuracy: 0.7602
# Epoch 67/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4686 - binary_accuracy: 0.7737 - val_loss: 0.4922 - val_binary_accuracy: 0.7593
# Epoch 68/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4668 - binary_accuracy: 0.7750 - val_loss: 0.4929 - val_binary_accuracy: 0.7609
# Epoch 69/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4648 - binary_accuracy: 0.7773 - val_loss: 0.5008 - val_binary_accuracy: 0.7590
# Epoch 70/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4672 - binary_accuracy: 0.7741 - val_loss: 0.4966 - val_binary_accuracy: 0.7574
# Epoch 71/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4667 - binary_accuracy: 0.7752 - val_loss: 0.4913 - val_binary_accuracy: 0.7597
# Epoch 72/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4638 - binary_accuracy: 0.7763 - val_loss: 0.4989 - val_binary_accuracy: 0.7547
# Training Accuracy: 0.777
# Validation Accuracy: 0.762

# %% [markdown]
# ###### Results:

# %% [markdown]
# - 300 dimension: CNN = 79.5% vs. 75.7%; RNN = 77.2% vs. 75.8%
# - 200 dimensions: CNN = 77.4% vs. 74.9% ; RNN = 77.7% vs. 76.2%
# - 100 dimensions: CNN = 78.3% vs. 74.8%; RNN = 72.7% vs. 72.6%
# - 50 dimensions: CNN = 77.7% vs. 74.5%; RNN = 73.8% vs. 73.6%
# - 200 dimensions worked especially well with RNNs; 300 dimensions worked better with CNNs (i.e. stick with 200 dimensions for now)

# %% [markdown]
# ##### Check if self-trained word embeddings help:

# %% [markdown]
# ###### Data Preparation:

# %%
# Define parameters for text processing 
max_features = 100000
max_len = 500
embedding_dim = 50

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer(num_words=100000)
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(tokenizer.num_words))
# Out:
# Included Token: 100000

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      240.113306
# std       243.629157
# min         0.000000
# 25%        88.000000
# 50%       165.000000
# 75%       305.000000
# max      2810.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 500)
# Shape of X_val: (37034, 500)

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, input_length=max_len))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Dropout(0.5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_21 (Embedding)     (None, 500, 50)           5000000
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 500, 64)           22464
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 100, 64)           0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 100, 64)           0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 100, 64)           28736
# _________________________________________________________________
# global_max_pooling1d_11 (Glo (None, 64)                0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 5,053,313
# Trainable params: 5,053,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 24s 50ms/step - loss: 0.5947 - binary_accuracy: 0.6839 - val_loss: 0.5109 - val_binary_accuracy: 0.7555
# Epoch 2/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4808 - binary_accuracy: 0.7712 - val_loss: 0.5046 - val_binary_accuracy: 0.7514
# Epoch 3/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4494 - binary_accuracy: 0.7910 - val_loss: 0.4962 - val_binary_accuracy: 0.7601
# Epoch 4/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4232 - binary_accuracy: 0.8079 - val_loss: 0.5014 - val_binary_accuracy: 0.7552
# Epoch 5/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.3943 - binary_accuracy: 0.8261 - val_loss: 0.5225 - val_binary_accuracy: 0.7421
# Epoch 6/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.3624 - binary_accuracy: 0.8439 - val_loss: 0.5269 - val_binary_accuracy: 0.7435
# Epoch 7/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.3293 - binary_accuracy: 0.8615 - val_loss: 0.5643 - val_binary_accuracy: 0.7481
# Epoch 8/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.2945 - binary_accuracy: 0.8805 - val_loss: 0.5934 - val_binary_accuracy: 0.7251
# Training Accuracy: 0.820
# Validation Accuracy: 0.760

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, input_length=max_len))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_23 (Embedding)     (None, 500, 50)           5000000
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 32)                10624
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 5,010,657
# Trainable params: 5,010,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 31s 69ms/step - loss: 0.5743 - binary_accuracy: 0.7006 - val_loss: 0.5065 - val_binary_accuracy: 0.7588
# Epoch 2/100
# 338/338 [==============================] - 17s 49ms/step - loss: 0.4775 - binary_accuracy: 0.7783 - val_loss: 0.5671 - val_binary_accuracy: 0.7508
# Epoch 3/100
# 338/338 [==============================] - 17s 51ms/step - loss: 0.4487 - binary_accuracy: 0.7965 - val_loss: 0.5154 - val_binary_accuracy: 0.7587
# Epoch 4/100
# 338/338 [==============================] - 17s 50ms/step - loss: 0.4268 - binary_accuracy: 0.8089 - val_loss: 0.5223 - val_binary_accuracy: 0.7411
# Epoch 5/100
#  15/338 [>.............................] - ETA: 14s - loss: 0.4022 - binary_accuracy: 0.8285

# %% [markdown]
# ###### Results:

# %% [markdown]
# - 100,000 tokens; 100 dimensions: CNN = 78.6% vs. 75.9%; RNN = 81.8% vs. 75.7%
# - 50,000 tokens; 100 dimensions: CNN = 78.8% vs. 75.8%; RNN = 78% vs. 75.7%
# - 100,000 tokens, 50 dimensions: CNN = 82% vs. 76%; RNN = 79.7% vs. 75.9%
# - using own word embeddings leads to strong overfitting, which also cannot be mitigated by using dropout

# %% [markdown]
# ##### Initialize Embeddings with Pre-Trained Weights and Fine-Tune Them:

# %% [markdown]
# ###### Data Preparation:

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.100.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 100
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 100000
max_len = 500
embedding_dim = 100

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(tokenizer.num_words))
# Out:
# Included Token: 100000

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      240.113306
# std       243.629157
# min         0.000000
# 25%        88.000000
# 50%       165.000000
# 75%       305.000000
# max      2810.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 500)
# Shape of X_val: (37034, 500)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (100000, 100)
# Number of Null Word Embeddings: 15

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=True))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 500, 100)          10000000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 500, 64)           44864
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 100, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 100, 64)           28736
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,075,713
# Trainable params: 10,075,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 21s 47ms/step - loss: 0.5822 - binary_accuracy: 0.6939 - val_loss: 0.4964 - val_binary_accuracy: 0.7604
# Epoch 2/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4768 - binary_accuracy: 0.7732 - val_loss: 0.5198 - val_binary_accuracy: 0.7442
# Epoch 3/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4417 - binary_accuracy: 0.7954 - val_loss: 0.4894 - val_binary_accuracy: 0.7641
# Epoch 4/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4043 - binary_accuracy: 0.8171 - val_loss: 0.5013 - val_binary_accuracy: 0.7596
# Epoch 5/100
# 338/338 [==============================] - 10s 28ms/step - loss: 0.3508 - binary_accuracy: 0.8491 - val_loss: 0.5530 - val_binary_accuracy: 0.7587
# Epoch 6/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.2829 - binary_accuracy: 0.8828 - val_loss: 0.6450 - val_binary_accuracy: 0.7524
# Epoch 7/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.2121 - binary_accuracy: 0.9145 - val_loss: 0.7109 - val_binary_accuracy: 0.7492
# Epoch 8/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.1485 - binary_accuracy: 0.9400 - val_loss: 0.8841 - val_binary_accuracy: 0.7270
# Training Accuracy: 0.831
# Validation Accuracy: 0.764

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=True))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 100)          10000000
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                17024
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,017,057
# Trainable params: 10,017,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 29s 67ms/step - loss: 0.5802 - binary_accuracy: 0.6938 - val_loss: 0.5074 - val_binary_accuracy: 0.7547
# Epoch 2/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4842 - binary_accuracy: 0.7732 - val_loss: 0.5083 - val_binary_accuracy: 0.7518
# Epoch 3/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.4531 - binary_accuracy: 0.7926 - val_loss: 0.5037 - val_binary_accuracy: 0.7551
# Epoch 4/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4262 - binary_accuracy: 0.8088 - val_loss: 0.5102 - val_binary_accuracy: 0.7506
# Epoch 5/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.3962 - binary_accuracy: 0.8247 - val_loss: 0.5331 - val_binary_accuracy: 0.7497
# Epoch 6/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.3663 - binary_accuracy: 0.8402 - val_loss: 0.5936 - val_binary_accuracy: 0.7372
# Epoch 7/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.3375 - binary_accuracy: 0.8545 - val_loss: 0.6202 - val_binary_accuracy: 0.7462
# Epoch 8/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.3052 - binary_accuracy: 0.8698 - val_loss: 0.6331 - val_binary_accuracy: 0.7358
# Epoch 9/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.2739 - binary_accuracy: 0.8854 - val_loss: 0.6754 - val_binary_accuracy: 0.7315
# Epoch 10/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.2471 - binary_accuracy: 0.8977 - val_loss: 0.7156 - val_binary_accuracy: 0.7292
# Training Accuracy: 0.818
# Validation Accuracy: 0.755

# %% [markdown]
# ###### Results:

# %% [markdown]
# - using pre-trained word embeddings and keeping them fixed leads to way less overfitting with comparable results
# - i.e. keep pre-trained embeddings

# %% [markdown]
# ##### Check how stopwords affect model performance:

# %% [markdown]
# ###### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["story"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.200.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 200
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 431789
max_len = 700
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(tokenizer.num_words))
# Out:
# Included Token: None

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      506.934945
# std       499.431631
# min         0.000000
# 25%       194.000000
# 50%       355.000000
# 75%       646.000000
# max      6766.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 700)
# Shape of X_val: (37034, 700)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (431789, 200)
# Number of Null Word Embeddings: 157

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 700, 200)          86357800
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 700, 64)           89664
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 140, 64)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 140, 64)           28736
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 86,478,313
# Trainable params: 120,513
# Non-trainable params: 86,357,800
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 20s 45ms/step - loss: 0.6209 - binary_accuracy: 0.6635 - val_loss: 0.5612 - val_binary_accuracy: 0.7074
# Epoch 2/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5667 - binary_accuracy: 0.7029 - val_loss: 0.5621 - val_binary_accuracy: 0.6964
# Epoch 3/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5489 - binary_accuracy: 0.7182 - val_loss: 0.5459 - val_binary_accuracy: 0.7317
# Epoch 4/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5389 - binary_accuracy: 0.7260 - val_loss: 0.5353 - val_binary_accuracy: 0.7378
# Epoch 5/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5307 - binary_accuracy: 0.7325 - val_loss: 0.5256 - val_binary_accuracy: 0.7362
# Epoch 6/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.5233 - binary_accuracy: 0.7361 - val_loss: 0.5207 - val_binary_accuracy: 0.7397
# Epoch 7/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.5159 - binary_accuracy: 0.7428 - val_loss: 0.5418 - val_binary_accuracy: 0.7237
# Epoch 8/100
# 338/338 [==============================] - 10s 28ms/step - loss: 0.5088 - binary_accuracy: 0.7472 - val_loss: 0.5277 - val_binary_accuracy: 0.7351
# Epoch 9/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5001 - binary_accuracy: 0.7535 - val_loss: 0.5486 - val_binary_accuracy: 0.7170
# Epoch 10/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4950 - binary_accuracy: 0.7562 - val_loss: 0.5491 - val_binary_accuracy: 0.7267
# Epoch 11/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4904 - binary_accuracy: 0.7590 - val_loss: 0.5183 - val_binary_accuracy: 0.7439
# Epoch 12/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4819 - binary_accuracy: 0.7650 - val_loss: 0.5434 - val_binary_accuracy: 0.7273
# Epoch 13/100
# 338/338 [==============================] - 10s 28ms/step - loss: 0.4754 - binary_accuracy: 0.7690 - val_loss: 0.5308 - val_binary_accuracy: 0.7324
# Epoch 14/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4711 - binary_accuracy: 0.7713 - val_loss: 0.5406 - val_binary_accuracy: 0.7310
# Epoch 15/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4638 - binary_accuracy: 0.7771 - val_loss: 0.5273 - val_binary_accuracy: 0.7358
# Epoch 16/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4610 - binary_accuracy: 0.7793 - val_loss: 0.5366 - val_binary_accuracy: 0.7270
# Training Accuracy: 0.782
# Validation Accuracy: 0.744

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 700, 200)          86357800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                29824
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 86,387,657
# Trainable params: 29,857
# Non-trainable params: 86,357,800
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 27s 67ms/step - loss: 0.6338 - binary_accuracy: 0.6489 - val_loss: 0.5916 - val_binary_accuracy: 0.6805
# Epoch 2/100
# 338/338 [==============================] - 18s 55ms/step - loss: 0.6076 - binary_accuracy: 0.6705 - val_loss: 0.6131 - val_binary_accuracy: 0.6947
# Epoch 3/100
# 338/338 [==============================] - 18s 55ms/step - loss: 0.5943 - binary_accuracy: 0.6814 - val_loss: 0.5771 - val_binary_accuracy: 0.7001
# Epoch 4/100
# 338/338 [==============================] - 18s 54ms/step - loss: 0.5868 - binary_accuracy: 0.6893 - val_loss: 0.5704 - val_binary_accuracy: 0.7019
# Epoch 5/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.5771 - binary_accuracy: 0.7007 - val_loss: 0.6457 - val_binary_accuracy: 0.6651
# Epoch 6/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5802 - binary_accuracy: 0.6933 - val_loss: 0.5573 - val_binary_accuracy: 0.7176
# Epoch 7/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5698 - binary_accuracy: 0.7050 - val_loss: 0.5889 - val_binary_accuracy: 0.7008
# Epoch 8/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5681 - binary_accuracy: 0.7032 - val_loss: 0.5569 - val_binary_accuracy: 0.7021
# Epoch 9/100
# 338/338 [==============================] - 18s 55ms/step - loss: 0.5631 - binary_accuracy: 0.7048 - val_loss: 0.5508 - val_binary_accuracy: 0.7116
# Epoch 10/100
# 338/338 [==============================] - 18s 55ms/step - loss: 0.5646 - binary_accuracy: 0.7032 - val_loss: 0.5499 - val_binary_accuracy: 0.7210
# Epoch 11/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5524 - binary_accuracy: 0.7167 - val_loss: 0.5605 - val_binary_accuracy: 0.7163
# Epoch 12/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5533 - binary_accuracy: 0.7135 - val_loss: 0.5532 - val_binary_accuracy: 0.6895
# Epoch 13/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.5496 - binary_accuracy: 0.7080 - val_loss: 0.5374 - val_binary_accuracy: 0.7261
# Epoch 14/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5511 - binary_accuracy: 0.7184 - val_loss: 0.5397 - val_binary_accuracy: 0.7268
# Epoch 15/100
# 338/338 [==============================] - 18s 54ms/step - loss: 0.5442 - binary_accuracy: 0.7226 - val_loss: 0.5584 - val_binary_accuracy: 0.6900
# Epoch 16/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5440 - binary_accuracy: 0.7165 - val_loss: 0.5394 - val_binary_accuracy: 0.7273
# Epoch 17/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5374 - binary_accuracy: 0.7252 - val_loss: 0.5427 - val_binary_accuracy: 0.7225
# Epoch 18/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5440 - binary_accuracy: 0.7151 - val_loss: 0.5418 - val_binary_accuracy: 0.7251
# Epoch 19/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5381 - binary_accuracy: 0.7226 - val_loss: 0.5828 - val_binary_accuracy: 0.7199
# Epoch 20/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5341 - binary_accuracy: 0.7280 - val_loss: 0.5497 - val_binary_accuracy: 0.6933
# Epoch 21/100
# 338/338 [==============================] - 19s 55ms/step - loss: 0.5318 - binary_accuracy: 0.7247 - val_loss: 0.5322 - val_binary_accuracy: 0.7214
# Training Accuracy: 0.729
# Validation Accuracy: 0.727

# %% [markdown]
# ###### Results:

# %% [markdown]
# - Stopwords Not Removed: CNN = 78.2% vs. 74.4%; RNN = 72.7%
# - i.e. NNs struggled when stopwords were not removed

# %% [markdown]
# ##### Check if adding additional text features can increase model performance:

# %% [markdown]
# ###### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["title"] + " " + kickstarter_df["blurb"] + " " + kickstarter_df["story"] + " " + kickstarter_df["risks"] + " " + kickstarter_df["creator_bio"] + " " + kickstarter_df["reward_description"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()
# Out:
# 100%|██████████| 246891/246891 [00:42<00:00, 5815.11it/s]

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.200.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 200
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 631377
max_len = 500
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(len(word_index)))
# Out:
# Included Token: 631377

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      509.529984
# std       409.239714
# min        14.000000
# 25%       241.000000
# 50%       399.000000
# 75%       649.000000
# max     11553.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 500)
# Shape of X_val: (37034, 500)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (631377, 200)
# Number of Null Word Embeddings: 218

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 500, 200)          126275400
# _________________________________________________________________
# conv1d (Conv1D)              (None, 500, 64)           89664
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 100, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 100, 64)           28736
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 126,395,913
# Trainable params: 120,513
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 19s 44ms/step - loss: 0.6020 - binary_accuracy: 0.6732 - val_loss: 0.5266 - val_binary_accuracy: 0.7350
# Epoch 2/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.5335 - binary_accuracy: 0.7296 - val_loss: 0.5457 - val_binary_accuracy: 0.7190
# Epoch 3/100
# 338/338 [==============================] - 10s 28ms/step - loss: 0.5154 - binary_accuracy: 0.7422 - val_loss: 0.5039 - val_binary_accuracy: 0.7557
# Epoch 4/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.5040 - binary_accuracy: 0.7519 - val_loss: 0.5097 - val_binary_accuracy: 0.7467
# Epoch 5/100
# 338/338 [==============================] - 10s 28ms/step - loss: 0.4928 - binary_accuracy: 0.7581 - val_loss: 0.4898 - val_binary_accuracy: 0.7611
# Epoch 6/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4780 - binary_accuracy: 0.7681 - val_loss: 0.4884 - val_binary_accuracy: 0.7634
# Epoch 7/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4667 - binary_accuracy: 0.7733 - val_loss: 0.4907 - val_binary_accuracy: 0.7603
# Epoch 8/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4585 - binary_accuracy: 0.7799 - val_loss: 0.4987 - val_binary_accuracy: 0.7638
# Epoch 9/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4450 - binary_accuracy: 0.7890 - val_loss: 0.5283 - val_binary_accuracy: 0.7517
# Epoch 10/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4337 - binary_accuracy: 0.7947 - val_loss: 0.5203 - val_binary_accuracy: 0.7557
# Epoch 11/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4237 - binary_accuracy: 0.8005 - val_loss: 0.4952 - val_binary_accuracy: 0.7649
# Epoch 12/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4118 - binary_accuracy: 0.8103 - val_loss: 0.5305 - val_binary_accuracy: 0.7524
# Epoch 13/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4044 - binary_accuracy: 0.8145 - val_loss: 0.5188 - val_binary_accuracy: 0.7598
# Epoch 14/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.3972 - binary_accuracy: 0.8177 - val_loss: 0.5441 - val_binary_accuracy: 0.7528
# Epoch 15/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.3838 - binary_accuracy: 0.8252 - val_loss: 0.5366 - val_binary_accuracy: 0.7338
# Epoch 16/100
# 338/338 [==============================] - 10s 29ms/step - loss: 0.3784 - binary_accuracy: 0.8288 - val_loss: 0.5430 - val_binary_accuracy: 0.7545
# Epoch 17/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.3669 - binary_accuracy: 0.8353 - val_loss: 0.5284 - val_binary_accuracy: 0.7544
# Epoch 18/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.3606 - binary_accuracy: 0.8389 - val_loss: 0.5693 - val_binary_accuracy: 0.7521
# Training Accuracy: 0.829
# Validation Accuracy: 0.765

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 200)          126275400
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                29824
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 126,305,257
# Trainable params: 29,857
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 23s 58ms/step - loss: 0.6131 - binary_accuracy: 0.6608 - val_loss: 0.6127 - val_binary_accuracy: 0.6198
# Epoch 2/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5699 - binary_accuracy: 0.7002 - val_loss: 0.5554 - val_binary_accuracy: 0.7226
# Epoch 3/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5604 - binary_accuracy: 0.7087 - val_loss: 0.5438 - val_binary_accuracy: 0.7176
# Epoch 4/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5570 - binary_accuracy: 0.7133 - val_loss: 0.5389 - val_binary_accuracy: 0.7255
# Epoch 5/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5514 - binary_accuracy: 0.7142 - val_loss: 0.5530 - val_binary_accuracy: 0.7065
# Epoch 6/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5580 - binary_accuracy: 0.7031 - val_loss: 0.5347 - val_binary_accuracy: 0.7300
# Epoch 7/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5470 - binary_accuracy: 0.7167 - val_loss: 0.5423 - val_binary_accuracy: 0.7236
# Epoch 8/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5421 - binary_accuracy: 0.7202 - val_loss: 0.5423 - val_binary_accuracy: 0.7313
# Epoch 9/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5387 - binary_accuracy: 0.7245 - val_loss: 0.5292 - val_binary_accuracy: 0.7288
# Epoch 10/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5361 - binary_accuracy: 0.7248 - val_loss: 0.5432 - val_binary_accuracy: 0.7223
# Epoch 11/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5336 - binary_accuracy: 0.7250 - val_loss: 0.5954 - val_binary_accuracy: 0.7228
# Epoch 12/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5336 - binary_accuracy: 0.7295 - val_loss: 0.5233 - val_binary_accuracy: 0.7364
# Epoch 13/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5375 - binary_accuracy: 0.7219 - val_loss: 0.5250 - val_binary_accuracy: 0.7356
# Epoch 14/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5249 - binary_accuracy: 0.7347 - val_loss: 0.5549 - val_binary_accuracy: 0.7261
# Epoch 15/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5263 - binary_accuracy: 0.7352 - val_loss: 0.5391 - val_binary_accuracy: 0.7080
# Epoch 16/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5327 - binary_accuracy: 0.7200 - val_loss: 0.5267 - val_binary_accuracy: 0.7290
# Epoch 17/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5246 - binary_accuracy: 0.7315 - val_loss: 0.5229 - val_binary_accuracy: 0.7253
# Epoch 18/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5302 - binary_accuracy: 0.7234 - val_loss: 0.5195 - val_binary_accuracy: 0.7331
# Epoch 19/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.5212 - binary_accuracy: 0.7347 - val_loss: 0.5215 - val_binary_accuracy: 0.7413
# Epoch 20/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5129 - binary_accuracy: 0.7413 - val_loss: 0.5127 - val_binary_accuracy: 0.7393
# Epoch 21/100
# 338/338 [==============================] - 16s 49ms/step - loss: 0.5155 - binary_accuracy: 0.7378 - val_loss: 0.5285 - val_binary_accuracy: 0.7223
# Epoch 22/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5446 - binary_accuracy: 0.7040 - val_loss: 0.5513 - val_binary_accuracy: 0.6998
# Epoch 23/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5482 - binary_accuracy: 0.6999 - val_loss: 0.5334 - val_binary_accuracy: 0.7254
# Epoch 24/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5386 - binary_accuracy: 0.7150 - val_loss: 0.5344 - val_binary_accuracy: 0.7223
# Epoch 25/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5240 - binary_accuracy: 0.7272 - val_loss: 0.5219 - val_binary_accuracy: 0.7374
# Epoch 26/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5154 - binary_accuracy: 0.7408 - val_loss: 0.5120 - val_binary_accuracy: 0.7454
# Epoch 27/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5094 - binary_accuracy: 0.7448 - val_loss: 0.5067 - val_binary_accuracy: 0.7467
# Epoch 28/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5063 - binary_accuracy: 0.7466 - val_loss: 0.5118 - val_binary_accuracy: 0.7480
# Epoch 29/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.5122 - binary_accuracy: 0.7427 - val_loss: 0.5064 - val_binary_accuracy: 0.7470
# Epoch 30/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5079 - binary_accuracy: 0.7484 - val_loss: 0.4995 - val_binary_accuracy: 0.7504
# Epoch 31/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.5037 - binary_accuracy: 0.7479 - val_loss: 0.5027 - val_binary_accuracy: 0.7479
# Epoch 32/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4990 - binary_accuracy: 0.7518 - val_loss: 0.5016 - val_binary_accuracy: 0.7519
# Epoch 33/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4946 - binary_accuracy: 0.7547 - val_loss: 0.4955 - val_binary_accuracy: 0.7545
# Epoch 34/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4952 - binary_accuracy: 0.7559 - val_loss: 0.4924 - val_binary_accuracy: 0.7561
# Epoch 35/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4922 - binary_accuracy: 0.7576 - val_loss: 0.4994 - val_binary_accuracy: 0.7555
# Epoch 36/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4922 - binary_accuracy: 0.7587 - val_loss: 0.4931 - val_binary_accuracy: 0.7558
# Epoch 37/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4925 - binary_accuracy: 0.7572 - val_loss: 0.5342 - val_binary_accuracy: 0.7257
# Epoch 38/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4954 - binary_accuracy: 0.7548 - val_loss: 0.4911 - val_binary_accuracy: 0.7582
# Epoch 39/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4899 - binary_accuracy: 0.7592 - val_loss: 0.4923 - val_binary_accuracy: 0.7526
# Epoch 40/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4862 - binary_accuracy: 0.7613 - val_loss: 0.4970 - val_binary_accuracy: 0.7578
# Epoch 41/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4862 - binary_accuracy: 0.7602 - val_loss: 0.4856 - val_binary_accuracy: 0.7591
# Epoch 42/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4813 - binary_accuracy: 0.7638 - val_loss: 0.4846 - val_binary_accuracy: 0.7599
# Epoch 43/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4828 - binary_accuracy: 0.7619 - val_loss: 0.4885 - val_binary_accuracy: 0.7607
# Epoch 44/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4780 - binary_accuracy: 0.7669 - val_loss: 0.4811 - val_binary_accuracy: 0.7628
# Epoch 45/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4761 - binary_accuracy: 0.7675 - val_loss: 0.4877 - val_binary_accuracy: 0.7610
# Epoch 46/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4760 - binary_accuracy: 0.7674 - val_loss: 0.5185 - val_binary_accuracy: 0.7388
# Epoch 47/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4748 - binary_accuracy: 0.7679 - val_loss: 0.4853 - val_binary_accuracy: 0.7591
# Epoch 48/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4722 - binary_accuracy: 0.7694 - val_loss: 0.4883 - val_binary_accuracy: 0.7629
# Epoch 49/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.4726 - binary_accuracy: 0.7696 - val_loss: 0.4804 - val_binary_accuracy: 0.7647
# Epoch 50/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4710 - binary_accuracy: 0.7707 - val_loss: 0.4846 - val_binary_accuracy: 0.7629
# Epoch 51/100
# 338/338 [==============================] - 16s 46ms/step - loss: 0.4677 - binary_accuracy: 0.7732 - val_loss: 0.4856 - val_binary_accuracy: 0.7651
# Epoch 52/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4655 - binary_accuracy: 0.7733 - val_loss: 0.4863 - val_binary_accuracy: 0.7594
# Epoch 53/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4671 - binary_accuracy: 0.7734 - val_loss: 0.4862 - val_binary_accuracy: 0.7629
# Epoch 54/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4615 - binary_accuracy: 0.7753 - val_loss: 0.4790 - val_binary_accuracy: 0.7655
# Epoch 55/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4645 - binary_accuracy: 0.7740 - val_loss: 0.4810 - val_binary_accuracy: 0.7610
# Epoch 56/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4627 - binary_accuracy: 0.7763 - val_loss: 0.4795 - val_binary_accuracy: 0.7634
# Epoch 57/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4614 - binary_accuracy: 0.7755 - val_loss: 0.4819 - val_binary_accuracy: 0.7674
# Epoch 58/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4610 - binary_accuracy: 0.7755 - val_loss: 0.4862 - val_binary_accuracy: 0.7636
# Epoch 59/100
# 338/338 [==============================] - 16s 48ms/step - loss: 0.4581 - binary_accuracy: 0.7777 - val_loss: 0.4791 - val_binary_accuracy: 0.7625
# Epoch 60/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4579 - binary_accuracy: 0.7788 - val_loss: 0.4773 - val_binary_accuracy: 0.7706
# Epoch 61/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4571 - binary_accuracy: 0.7795 - val_loss: 0.4728 - val_binary_accuracy: 0.7704
# Epoch 62/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4552 - binary_accuracy: 0.7810 - val_loss: 0.4740 - val_binary_accuracy: 0.7706
# Epoch 63/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4549 - binary_accuracy: 0.7808 - val_loss: 0.4785 - val_binary_accuracy: 0.7657
# Epoch 64/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4544 - binary_accuracy: 0.7820 - val_loss: 0.4752 - val_binary_accuracy: 0.7690
# Epoch 65/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4526 - binary_accuracy: 0.7814 - val_loss: 0.4802 - val_binary_accuracy: 0.7675
# Epoch 66/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4500 - binary_accuracy: 0.7847 - val_loss: 0.4752 - val_binary_accuracy: 0.7669
# Epoch 67/100
# 338/338 [==============================] - 16s 47ms/step - loss: 0.4512 - binary_accuracy: 0.7824 - val_loss: 0.4761 - val_binary_accuracy: 0.7670
# Training Accuracy: 0.782
# Validation Accuracy: 0.771

# %% [markdown]
# ###### Results:

# %% [markdown]
# - Title + Blurb + Story: CNN = 78.1% vs. 75.5%; RNN = 76.6% vs. 75.9%
# - Title + Blurb + Story + Risks: CNN = 78.7% vs. 75.7%; RNN = 77.7% vs. 76.5%
# - Title + Blurb + Story + Risks + Creator_Bio: CNN = 79.1% vs. 76.3%; RNN = 78% vs. 76.8%
# - Title + Blurb + Story + Risks + Creator_Bio + Reward_Description: CNN = 82.9% vs. 76.5%; RNN = 78.2% vs. 77.1%
# - i.e. using all text attributes helped to increase predictive performance

# %% [markdown]
# ##### Fine-Tune Max_Len:

# %% [markdown]
# ###### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["title"] + " " + kickstarter_df["blurb"] + " " + kickstarter_df["story"] + " " + kickstarter_df["risks"] + " " + kickstarter_df["creator_bio"] + " " + kickstarter_df["reward_description"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()
# Out:
# 100%|██████████| 246891/246891 [00:42<00:00, 5780.91it/s]

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.200.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 200
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 631377
max_len = 300
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(len(word_index)))
# Out:
# Included Token: 631377

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      509.529984
# std       409.239714
# min        14.000000
# 25%       241.000000
# 50%       399.000000
# 75%       649.000000
# max     11553.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 300)
# Shape of X_val: (37034, 300)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (631377, 200)
# Number of Null Word Embeddings: 218

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 300, 200)          126275400
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 300, 64)           89664
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 60, 64)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 60, 64)            28736
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 126,395,913
# Trainable params: 120,513
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 16s 38ms/step - loss: 0.5992 - binary_accuracy: 0.6811 - val_loss: 0.5283 - val_binary_accuracy: 0.7330
# Epoch 2/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5357 - binary_accuracy: 0.7276 - val_loss: 0.5407 - val_binary_accuracy: 0.7212
# Epoch 3/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5173 - binary_accuracy: 0.7402 - val_loss: 0.5139 - val_binary_accuracy: 0.7433
# Epoch 4/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.5066 - binary_accuracy: 0.7492 - val_loss: 0.5114 - val_binary_accuracy: 0.7426
# Epoch 5/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4960 - binary_accuracy: 0.7573 - val_loss: 0.4954 - val_binary_accuracy: 0.7569
# Epoch 6/100
# 338/338 [==============================] - 9s 28ms/step - loss: 0.4848 - binary_accuracy: 0.7625 - val_loss: 0.5203 - val_binary_accuracy: 0.7472
# Epoch 7/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4735 - binary_accuracy: 0.7702 - val_loss: 0.5040 - val_binary_accuracy: 0.7542
# Epoch 8/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4643 - binary_accuracy: 0.7757 - val_loss: 0.5036 - val_binary_accuracy: 0.7479
# Epoch 9/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4490 - binary_accuracy: 0.7863 - val_loss: 0.5021 - val_binary_accuracy: 0.7577
# Epoch 10/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4382 - binary_accuracy: 0.7925 - val_loss: 0.5968 - val_binary_accuracy: 0.7275
# Epoch 11/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4274 - binary_accuracy: 0.7996 - val_loss: 0.5189 - val_binary_accuracy: 0.7555
# Epoch 12/100
# 338/338 [==============================] - 9s 26ms/step - loss: 0.4177 - binary_accuracy: 0.8038 - val_loss: 0.5446 - val_binary_accuracy: 0.7516
# Epoch 13/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.4073 - binary_accuracy: 0.8123 - val_loss: 0.5207 - val_binary_accuracy: 0.7488
# Epoch 14/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.3974 - binary_accuracy: 0.8152 - val_loss: 0.5781 - val_binary_accuracy: 0.7513
# Epoch 15/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.3912 - binary_accuracy: 0.8191 - val_loss: 0.5415 - val_binary_accuracy: 0.7330
# Epoch 16/100
# 338/338 [==============================] - 9s 27ms/step - loss: 0.3837 - binary_accuracy: 0.8236 - val_loss: 0.5421 - val_binary_accuracy: 0.7481
# Training Accuracy: 0.809
# Validation Accuracy: 0.758

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 300, 200)          126275400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 32)                29824
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 126,305,257
# Trainable params: 29,857
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 21s 50ms/step - loss: 0.6142 - binary_accuracy: 0.6607 - val_loss: 0.5861 - val_binary_accuracy: 0.7038
# Epoch 2/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5728 - binary_accuracy: 0.6997 - val_loss: 0.5471 - val_binary_accuracy: 0.7227
# Epoch 3/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5553 - binary_accuracy: 0.7194 - val_loss: 0.5525 - val_binary_accuracy: 0.7120
# Epoch 4/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5514 - binary_accuracy: 0.7214 - val_loss: 0.6184 - val_binary_accuracy: 0.6807
# Epoch 5/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5542 - binary_accuracy: 0.7094 - val_loss: 0.5422 - val_binary_accuracy: 0.7278
# Epoch 6/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5479 - binary_accuracy: 0.7163 - val_loss: 0.5731 - val_binary_accuracy: 0.6828
# Epoch 7/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5523 - binary_accuracy: 0.7076 - val_loss: 0.5351 - val_binary_accuracy: 0.7236
# Epoch 8/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5400 - binary_accuracy: 0.7236 - val_loss: 0.5264 - val_binary_accuracy: 0.7344
# Epoch 9/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5305 - binary_accuracy: 0.7323 - val_loss: 0.5324 - val_binary_accuracy: 0.7256
# Epoch 10/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5375 - binary_accuracy: 0.7264 - val_loss: 0.5508 - val_binary_accuracy: 0.7267
# Epoch 11/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5307 - binary_accuracy: 0.7319 - val_loss: 0.5206 - val_binary_accuracy: 0.7342
# Epoch 12/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5291 - binary_accuracy: 0.7326 - val_loss: 0.5486 - val_binary_accuracy: 0.7309
# Epoch 13/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5301 - binary_accuracy: 0.7324 - val_loss: 0.5395 - val_binary_accuracy: 0.7150
# Epoch 14/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5295 - binary_accuracy: 0.7315 - val_loss: 0.5205 - val_binary_accuracy: 0.7337
# Epoch 15/100
# 338/338 [==============================] - 13s 39ms/step - loss: 0.5268 - binary_accuracy: 0.7326 - val_loss: 0.5289 - val_binary_accuracy: 0.7249
# Training Accuracy: 0.736
# Validation Accuracy: 0.734

# %% [markdown]
# ###### Results:

# %% [markdown]
# - max_len=300: CNN = 80.9% vs. 75.8%; RNN = 73.6% vs. 73.4%
# - max_len=500: CNN = 82.9% vs. 76.5%; RNN = 78.2% vs. 77.1%
# - max_len=700: CNN = 82.8% vs. 76.2%; RNN = 79% vs. 77.4%
# - max_len=1000: CNN = 81% vs. 76.8%; RNN = 78.9% vs, 77.5%
# - max_len=3000: CNN = 80.2% vs. 76.6%; RNN = takes too long to train
# - i.e. max_len between 700 and 1000 provides the best trade-off between training time and accuracy

# %% [markdown]
# ##### Fine-Tune Max_Features:

# %% [markdown]
# ###### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["title"] + " " + kickstarter_df["blurb"] + " " + kickstarter_df["story"] + " " + kickstarter_df["risks"] + " " + kickstarter_df["creator_bio"] + " " + kickstarter_df["reward_description"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()
# Out:
# 100%|██████████| 246891/246891 [00:42<00:00, 5753.81it/s]

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.200.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 200
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 50000
max_len = 700
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(tokenizer.num_words))
# Out:
# Included Token: 50000

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      495.489689
# std       396.125344
# min        14.000000
# 25%       235.000000
# 50%       388.000000
# 75%       631.000000
# max     11407.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 700)
# Shape of X_val: (37034, 700)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (50000, 200)
# Number of Null Word Embeddings: 5

# %% [markdown]
# ###### Convolutional Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(MaxPool1D(5))
  model.add(Conv1D(64, 7, activation='relu', padding='same'))
  model.add(GlobalMaxPool1D())
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 700, 200)          10000000
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 700, 64)           89664
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 140, 64)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 140, 64)           28736
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,120,513
# Trainable params: 120,513
# Non-trainable params: 10,000,000
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 18s 40ms/step - loss: 0.6009 - binary_accuracy: 0.6788 - val_loss: 0.5264 - val_binary_accuracy: 0.7364
# Epoch 2/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.5355 - binary_accuracy: 0.7300 - val_loss: 0.5391 - val_binary_accuracy: 0.7206
# Epoch 3/100
# 338/338 [==============================] - 8s 25ms/step - loss: 0.5160 - binary_accuracy: 0.7413 - val_loss: 0.5040 - val_binary_accuracy: 0.7506
# Epoch 4/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.5028 - binary_accuracy: 0.7536 - val_loss: 0.5128 - val_binary_accuracy: 0.7447
# Epoch 5/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4919 - binary_accuracy: 0.7575 - val_loss: 0.4898 - val_binary_accuracy: 0.7611
# Epoch 6/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4793 - binary_accuracy: 0.7666 - val_loss: 0.4940 - val_binary_accuracy: 0.7572
# Epoch 7/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4661 - binary_accuracy: 0.7748 - val_loss: 0.4998 - val_binary_accuracy: 0.7489
# Epoch 8/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4550 - binary_accuracy: 0.7820 - val_loss: 0.4899 - val_binary_accuracy: 0.7580
# Epoch 9/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4405 - binary_accuracy: 0.7911 - val_loss: 0.5023 - val_binary_accuracy: 0.7578
# Epoch 10/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4313 - binary_accuracy: 0.7952 - val_loss: 0.5659 - val_binary_accuracy: 0.7352
# Epoch 11/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4199 - binary_accuracy: 0.8033 - val_loss: 0.5120 - val_binary_accuracy: 0.7469
# Epoch 12/100
# 338/338 [==============================] - 8s 24ms/step - loss: 0.4080 - binary_accuracy: 0.8110 - val_loss: 0.5128 - val_binary_accuracy: 0.7512
# Training Accuracy: 0.784
# Validation Accuracy: 0.761

# %% [markdown]
# ###### Recurrent Neural Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(LSTM(32))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 700, 200)          10000000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                29824
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,029,857
# Trainable params: 29,857
# Non-trainable params: 10,000,000
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 26s 64ms/step - loss: 0.6105 - binary_accuracy: 0.6597 - val_loss: 0.5527 - val_binary_accuracy: 0.7155
# Epoch 2/100
# 338/338 [==============================] - 17s 52ms/step - loss: 0.5596 - binary_accuracy: 0.7111 - val_loss: 0.5535 - val_binary_accuracy: 0.7265
# Epoch 3/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.5527 - binary_accuracy: 0.7193 - val_loss: 0.5677 - val_binary_accuracy: 0.6912
# Epoch 4/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5520 - binary_accuracy: 0.7195 - val_loss: 0.5328 - val_binary_accuracy: 0.7309
# Epoch 5/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5524 - binary_accuracy: 0.7131 - val_loss: 0.5436 - val_binary_accuracy: 0.7245
# Epoch 6/100
# 338/338 [==============================] - 17s 52ms/step - loss: 0.5470 - binary_accuracy: 0.7102 - val_loss: 0.5432 - val_binary_accuracy: 0.7277
# Epoch 7/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5537 - binary_accuracy: 0.7087 - val_loss: 0.5583 - val_binary_accuracy: 0.7184
# Epoch 8/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5418 - binary_accuracy: 0.7217 - val_loss: 0.5344 - val_binary_accuracy: 0.7349
# Epoch 9/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5337 - binary_accuracy: 0.7306 - val_loss: 0.5455 - val_binary_accuracy: 0.7040
# Epoch 10/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5351 - binary_accuracy: 0.7255 - val_loss: 0.5198 - val_binary_accuracy: 0.7331
# Epoch 11/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.5336 - binary_accuracy: 0.7207 - val_loss: 0.5333 - val_binary_accuracy: 0.7387
# Epoch 12/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5313 - binary_accuracy: 0.7310 - val_loss: 0.5260 - val_binary_accuracy: 0.7274
# Epoch 13/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5298 - binary_accuracy: 0.7298 - val_loss: 0.5159 - val_binary_accuracy: 0.7378
# Epoch 14/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.5248 - binary_accuracy: 0.7337 - val_loss: 0.5193 - val_binary_accuracy: 0.7407
# Epoch 15/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5215 - binary_accuracy: 0.7369 - val_loss: 0.5271 - val_binary_accuracy: 0.7351
# Epoch 16/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5234 - binary_accuracy: 0.7327 - val_loss: 0.5105 - val_binary_accuracy: 0.7450
# Epoch 17/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5137 - binary_accuracy: 0.7406 - val_loss: 0.5107 - val_binary_accuracy: 0.7412
# Epoch 18/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5178 - binary_accuracy: 0.7382 - val_loss: 0.5390 - val_binary_accuracy: 0.7045
# Epoch 19/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.5160 - binary_accuracy: 0.7390 - val_loss: 0.5101 - val_binary_accuracy: 0.7438
# Epoch 20/100
# 338/338 [==============================] - 17s 52ms/step - loss: 0.5122 - binary_accuracy: 0.7410 - val_loss: 0.5117 - val_binary_accuracy: 0.7470
# Epoch 21/100
# 338/338 [==============================] - 17s 52ms/step - loss: 0.5077 - binary_accuracy: 0.7459 - val_loss: 0.5036 - val_binary_accuracy: 0.7484
# Epoch 22/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5093 - binary_accuracy: 0.7437 - val_loss: 0.5018 - val_binary_accuracy: 0.7494
# Epoch 23/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5064 - binary_accuracy: 0.7466 - val_loss: 0.5187 - val_binary_accuracy: 0.7280
# Epoch 24/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5063 - binary_accuracy: 0.7453 - val_loss: 0.5072 - val_binary_accuracy: 0.7458
# Epoch 25/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5020 - binary_accuracy: 0.7504 - val_loss: 0.5025 - val_binary_accuracy: 0.7503
# Epoch 26/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5014 - binary_accuracy: 0.7485 - val_loss: 0.5021 - val_binary_accuracy: 0.7497
# Epoch 27/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4998 - binary_accuracy: 0.7516 - val_loss: 0.4962 - val_binary_accuracy: 0.7528
# Epoch 28/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.5027 - binary_accuracy: 0.7487 - val_loss: 0.5068 - val_binary_accuracy: 0.7487
# Epoch 29/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.5012 - binary_accuracy: 0.7503 - val_loss: 0.4955 - val_binary_accuracy: 0.7543
# Epoch 30/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4970 - binary_accuracy: 0.7538 - val_loss: 0.4987 - val_binary_accuracy: 0.7525
# Epoch 31/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4960 - binary_accuracy: 0.7550 - val_loss: 0.4907 - val_binary_accuracy: 0.7566
# Epoch 32/100
# 338/338 [==============================] - 17s 52ms/step - loss: 0.4921 - binary_accuracy: 0.7564 - val_loss: 0.4973 - val_binary_accuracy: 0.7495
# Epoch 33/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4904 - binary_accuracy: 0.7583 - val_loss: 0.4907 - val_binary_accuracy: 0.7591
# Epoch 34/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4898 - binary_accuracy: 0.7595 - val_loss: 0.4961 - val_binary_accuracy: 0.7563
# Epoch 35/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4879 - binary_accuracy: 0.7607 - val_loss: 0.4997 - val_binary_accuracy: 0.7584
# Epoch 36/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.4859 - binary_accuracy: 0.7615 - val_loss: 0.4955 - val_binary_accuracy: 0.7541
# Epoch 37/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4885 - binary_accuracy: 0.7595 - val_loss: 0.4895 - val_binary_accuracy: 0.7577
# Epoch 38/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4836 - binary_accuracy: 0.7626 - val_loss: 0.4875 - val_binary_accuracy: 0.7592
# Epoch 39/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4842 - binary_accuracy: 0.7637 - val_loss: 0.4870 - val_binary_accuracy: 0.7609
# Epoch 40/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4839 - binary_accuracy: 0.7630 - val_loss: 0.4910 - val_binary_accuracy: 0.7619
# Epoch 41/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4854 - binary_accuracy: 0.7621 - val_loss: 0.4897 - val_binary_accuracy: 0.7619
# Epoch 42/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4788 - binary_accuracy: 0.7651 - val_loss: 0.4878 - val_binary_accuracy: 0.7602
# Epoch 43/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4806 - binary_accuracy: 0.7644 - val_loss: 0.4863 - val_binary_accuracy: 0.7598
# Epoch 44/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4776 - binary_accuracy: 0.7671 - val_loss: 0.4807 - val_binary_accuracy: 0.7640
# Epoch 45/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4774 - binary_accuracy: 0.7678 - val_loss: 0.4805 - val_binary_accuracy: 0.7632
# Epoch 46/100
# 338/338 [==============================] - 18s 53ms/step - loss: 0.4767 - binary_accuracy: 0.7675 - val_loss: 0.4869 - val_binary_accuracy: 0.7612
# Epoch 47/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4775 - binary_accuracy: 0.7695 - val_loss: 0.4874 - val_binary_accuracy: 0.7615
# Epoch 48/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4751 - binary_accuracy: 0.7684 - val_loss: 0.4890 - val_binary_accuracy: 0.7627
# Epoch 49/100
# 338/338 [==============================] - 17s 52ms/step - loss: 0.4796 - binary_accuracy: 0.7669 - val_loss: 0.4805 - val_binary_accuracy: 0.7635
# Epoch 50/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4743 - binary_accuracy: 0.7691 - val_loss: 0.4891 - val_binary_accuracy: 0.7594
# Epoch 51/100
# 338/338 [==============================] - 18s 52ms/step - loss: 0.4724 - binary_accuracy: 0.7709 - val_loss: 0.5000 - val_binary_accuracy: 0.7614
# Training Accuracy: 0.770
# Validation Accuracy: 0.764

# %% [markdown]
# ###### Results:

# %% [markdown]
# - max_features = None: CNN = 81% vs. 76.8%; RNN = 78.9% vs, 77.5%
# - max_features = 200,000: CNN = 83.1% vs. 76.2%; RNN = 78.2% vs. 77.1%
# - max_features = 100,000: CNN = 79.5% vs. 76.4%; RNN = 73.2% vs. 73.1%
# - max_features = 50,000: CNN = 78.4% vs. 76.1%; RNN = 77% vs. 76.4%
# - i.e. including all tokens helps to increase model performance (but also higher overfitting, which need to be addressed)

# %% [markdown]
# #### c) Fine-Tune CNN Model

# %% [markdown]
# ##### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["title"] + " " + kickstarter_df["blurb"] + " " + kickstarter_df["story"] + " " + kickstarter_df["risks"] + " " + kickstarter_df["creator_bio"] + " " + kickstarter_df["reward_description"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()
# Out:
# 100%|██████████| 246891/246891 [00:43<00:00, 5674.08it/s]

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.200.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 200
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 631377
max_len = 1000
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(len(word_index)))
# Out:
# Included Token: 631377

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      509.529984
# std       409.239714
# min        14.000000
# 25%       241.000000
# 50%       399.000000
# 75%       649.000000
# max     11553.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 1000)
# Shape of X_val: (37034, 1000)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (631377, 200)
# Number of Null Word Embeddings: 218

# %% [markdown]
# ##### Fine-Tune Network Architecture:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D(2))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D(2))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D(2))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D())
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_69 (Embedding)     (None, 1000, 200)         126275400
# _________________________________________________________________
# conv1d_221 (Conv1D)          (None, 1000, 64)          64064
# _________________________________________________________________
# average_pooling1d_52 (Averag (None, 500, 64)           0
# _________________________________________________________________
# conv1d_222 (Conv1D)          (None, 500, 64)           20544
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 500, 64)           0
# _________________________________________________________________
# average_pooling1d_53 (Averag (None, 250, 64)           0
# _________________________________________________________________
# conv1d_223 (Conv1D)          (None, 250, 64)           20544
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 250, 64)           0
# _________________________________________________________________
# average_pooling1d_54 (Averag (None, 125, 64)           0
# _________________________________________________________________
# conv1d_224 (Conv1D)          (None, 125, 64)           20544
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 125, 64)           0
# _________________________________________________________________
# average_pooling1d_55 (Averag (None, 62, 64)            0
# _________________________________________________________________
# flatten_61 (Flatten)         (None, 3968)              0
# _________________________________________________________________
# dense_129 (Dense)            (None, 32)                127008
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dense_130 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 126,528,137
# Trainable params: 252,737
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=5, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 23s 52ms/step - loss: 0.5981 - binary_accuracy: 0.6652 - val_loss: 0.5252 - val_binary_accuracy: 0.7326
# Epoch 2/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.5309 - binary_accuracy: 0.7275 - val_loss: 0.5120 - val_binary_accuracy: 0.7384
# Epoch 3/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.5158 - binary_accuracy: 0.7402 - val_loss: 0.5153 - val_binary_accuracy: 0.7355
# Epoch 4/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.5087 - binary_accuracy: 0.7467 - val_loss: 0.4932 - val_binary_accuracy: 0.7560
# Epoch 5/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.5035 - binary_accuracy: 0.7491 - val_loss: 0.5099 - val_binary_accuracy: 0.7426
# Epoch 6/100
# 338/338 [==============================] - 11s 33ms/step - loss: 0.4947 - binary_accuracy: 0.7544 - val_loss: 0.5264 - val_binary_accuracy: 0.7412
# Epoch 7/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4916 - binary_accuracy: 0.7569 - val_loss: 0.4948 - val_binary_accuracy: 0.7516
# Epoch 8/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4842 - binary_accuracy: 0.7619 - val_loss: 0.4897 - val_binary_accuracy: 0.7586
# Epoch 9/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4743 - binary_accuracy: 0.7697 - val_loss: 0.4912 - val_binary_accuracy: 0.7568
# Epoch 10/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4707 - binary_accuracy: 0.7721 - val_loss: 0.5122 - val_binary_accuracy: 0.7482
# Epoch 11/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4642 - binary_accuracy: 0.7765 - val_loss: 0.4998 - val_binary_accuracy: 0.7605
# Epoch 12/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4577 - binary_accuracy: 0.7804 - val_loss: 0.5070 - val_binary_accuracy: 0.7516
# Epoch 13/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4505 - binary_accuracy: 0.7864 - val_loss: 0.5102 - val_binary_accuracy: 0.7506
# Epoch 14/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4437 - binary_accuracy: 0.7894 - val_loss: 0.5113 - val_binary_accuracy: 0.7500
# Epoch 15/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4347 - binary_accuracy: 0.7954 - val_loss: 0.5204 - val_binary_accuracy: 0.7415
# Epoch 16/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4271 - binary_accuracy: 0.7994 - val_loss: 0.5117 - val_binary_accuracy: 0.7490
# Training Accuracy: 0.787
# Validation Accuracy: 0.760

# %% [markdown]
# Result:
# - 1 CNN Layer, 1 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 2: 77.9% vs. 74.6%
# - 1 CNN Layer, 1 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 5: 79.5% vs. 75%
# - 1 CNN Layer, 1 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 10: 82% vs. 75.4%
# - 1 CNN Layer, 1 Dense Layers, 32 Filters, Kernel Size 7, Pooling Size 10: 77.3% vs. 75.3%
# - 1 CNN Layer, 1 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10: 78.7% vs. 75.5%
# -> i.e. the less parameters before the output layer, the less overfitting
# - 1 CNN Layer, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons 32: 79.6% vs. 76.1%
# - 1 CNN Layer, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons 64: 76.9% vs. 75.7%
# - 1 CNN Layer, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons 16: 78.3% vs. 75.9%
# - 1 CNN Layer, 3 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons [64,16]: 78.8% vs. 75.9%
# - 1 CNN Layer, 3 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons [32,8]: 78.1% vs. 75.8%
# -> i.e. adding an additional hidden Dense layer helps to improve performance (stick first with 1 hidden layer)
# - 2 CNN Layers, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons 32: 78.2% vs. 76.2%
# - 2 CNN Layers, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons 16: 79.1% vs. 76%
# - 2 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 10, Dense Neurons 32: 79.1% vs. 76.5%
# - 2 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 5, Dense Neurons 32: 79.4% vs. 76.5%
# - 2 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 79.7% vs. 76.7%
# - 2 CNN Layers, 2 Dense Layers, 32 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 78.7% vs. 76.6%
# -> i.e. adding an additional CNN layer helps
# - 3 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 82.7% vs. 76.6%
# - 3 CNN Layers, 2 Dense Layers, 32 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 79.8% vs. 76.9%
# - 3 CNN Layers, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 77.5% vs. 76.5%
# - 4 CNN Layers, 2 Dense Layers, 32 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 80% vs. 77%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 79% vs. 77.1%
# - 4 CNN Layers, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 78.6% vs. 77%
# - 5 CNN Layers, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 78.7% vs. 76.7%
# - 5 CNN Layers, 2 Dense Layers, 32 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 78.9% vs. 77%
# - 5 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 80.1% vs. 76.9%
# - 6 CNN Layers, 2 Dense Layers, 32 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 80.5% vs. 76.8%
# - 6 CNN Layers, 2 Dense Layers, 16 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 78.9% vs. 76.6%
# -> i.e. 4 CNN layers worked the best; 32-64 filters worked the best; pooling of 2 worked the best
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 3, Pooling Size 2, Dense Neurons 32: 77.5% vs. 76.6%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32: 80.6% vs. 77.4%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 7, Pooling Size 2, Dense Neurons 32: 79% vs. 77.1%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 10, Pooling Size 2, Dense Neurons 32: 78.5% vs. 76.7%
# -> i.e. kernel size of 5 performs the best
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32: 80.6% vs. 77.4%
# - 4 CNN Layers, 2 Dense Layers, 32 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32: 77.2% vs. 76.6%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 64: 78% vs. 76.6%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 16: 80.9% vs. 77.2%
# - 4 CNN Layers, 3 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons [64,16]: 83.5% vs. 76.5%
# - 4 CNN Layers, 3 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons [32,32]: 80.2% vs. 77.4%
# - 4 CNN Layers, 3 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons [64,64]: 78.2% vs. 76.9%
# - 4 CNN Layers, 3 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons [16,16]: 80.8% vs. 77.2%
# -> i.e. 2 Dense Layers with 32 hidden units provided best results
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, padding=same: 80.6% vs. 77.4%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, padding=valid: 79.3% vs. 77.2%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, padding=causal: 80.3% vs. 77.2%
# -> i.e. same padding is a little bit better
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=max, flatten: 80.6% vs. 77.4%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten: 80.1% vs. 77.5%
# - 4 CNN Layers, 1 Dense Layer, 64 Filters, Kernel Size 5, Pooling Size 2, pooling=avg, global: 80.9% vs. 77.1%
# - 4 CNN Layers, 1 Dense Layer, 64 Filters, Kernel Size 5, Pooling Size 2, pooling=max, global: 79.5% vs. 76.5%
# -> i.e. average pooling with flatten provided the best results
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, relu: 80.4% vs. 77.4%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, elu: 76.5% vs. 75.1%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, selu: 75.3% vs. 73.5%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, gelu: 76.5% vs. 75.6%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, swish: 79% vs. 75.9%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, tanh: 78% vs. 74.5%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, sigmoid: 74.8% vs. 74.6%
# - 4 CNN Layers, 2 Dense Layers, 64 Filters, Kernel Size 5, Pooling Size 2, Dense Neurons 32, pooling=avg, flatten, leaky relu: 78.7% vs. 76%
# -> i.e. relu activation was the best

# %% [markdown]
# ##### Add Regularization To The Network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same'))
  model.add(AvgPool1D())
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1000, 200)         126275400
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 1000, 64)          64064
# _________________________________________________________________
# average_pooling1d_4 (Average (None, 500, 64)           0
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 500, 64)           0
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 500, 64)           128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 500, 64)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 500, 64)           20544
# _________________________________________________________________
# average_pooling1d_5 (Average (None, 250, 64)           0
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 250, 64)           0
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 250, 64)           128
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 250, 64)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 250, 64)           20544
# _________________________________________________________________
# average_pooling1d_6 (Average (None, 125, 64)           0
# _________________________________________________________________
# gaussian_noise_3 (GaussianNo (None, 125, 64)           0
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 125, 64)           128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 125, 64)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 125, 64)           20544
# _________________________________________________________________
# average_pooling1d_7 (Average (None, 62, 64)            0
# _________________________________________________________________
# gaussian_noise_4 (GaussianNo (None, 62, 64)            0
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 62, 64)            128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 62, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3968)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                127008
# _________________________________________________________________
# gaussian_noise_5 (GaussianNo (None, 32)                0
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 32)                64
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 126,528,713
# Trainable params: 253,313
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=10, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 28s 60ms/step - loss: 2.1265 - binary_accuracy: 0.6202 - val_loss: 0.6253 - val_binary_accuracy: 0.6767
# Epoch 2/100
# 338/338 [==============================] - 11s 33ms/step - loss: 0.6282 - binary_accuracy: 0.6766 - val_loss: 0.5976 - val_binary_accuracy: 0.6986
# Epoch 3/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6206 - binary_accuracy: 0.6864 - val_loss: 0.6131 - val_binary_accuracy: 0.6825
# Epoch 4/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6171 - binary_accuracy: 0.6918 - val_loss: 0.6744 - val_binary_accuracy: 0.5937
# Epoch 5/100
# 338/338 [==============================] - 11s 34ms/step - loss: 0.6178 - binary_accuracy: 0.6889 - val_loss: 0.5875 - val_binary_accuracy: 0.7204
# Epoch 6/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6187 - binary_accuracy: 0.6932 - val_loss: 0.5889 - val_binary_accuracy: 0.7190
# Epoch 7/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6203 - binary_accuracy: 0.6968 - val_loss: 0.6072 - val_binary_accuracy: 0.6986
# Epoch 8/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6189 - binary_accuracy: 0.6981 - val_loss: 0.5876 - val_binary_accuracy: 0.7218
# Epoch 9/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6138 - binary_accuracy: 0.7028 - val_loss: 0.5872 - val_binary_accuracy: 0.7246
# Epoch 10/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6156 - binary_accuracy: 0.7004 - val_loss: 0.5972 - val_binary_accuracy: 0.7123
# Epoch 11/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6137 - binary_accuracy: 0.7014 - val_loss: 0.5944 - val_binary_accuracy: 0.7087
# Epoch 12/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6100 - binary_accuracy: 0.7018 - val_loss: 0.5842 - val_binary_accuracy: 0.7226
# Epoch 13/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6107 - binary_accuracy: 0.7031 - val_loss: 0.6003 - val_binary_accuracy: 0.7105
# Epoch 14/100
# 338/338 [==============================] - 12s 35ms/step - loss: 0.6067 - binary_accuracy: 0.7044 - val_loss: 0.5842 - val_binary_accuracy: 0.7173
# Epoch 15/100
# 338/338 [==============================] - 12s 35ms/step - loss: 0.6049 - binary_accuracy: 0.7044 - val_loss: 0.5803 - val_binary_accuracy: 0.7198
# Epoch 16/100
# 338/338 [==============================] - 12s 34ms/step - loss: 0.6058 - binary_accuracy: 0.7027 - val_loss: 0.5776 - val_binary_accuracy: 0.7239
# Epoch 17/100
# 338/338 [==============================] - 12s 35ms/step - loss: 0.6025 - binary_accuracy: 0.7064 - val_loss: 0.5828 - val_binary_accuracy: 0.7179
# Epoch 18/100
# 338/338 [==============================] - 12s 35ms/step - loss: 0.6027 - binary_accuracy: 0.7046 - val_loss: 0.5763 - val_binary_accuracy: 0.7206
# Epoch 19/100
# 338/338 [==============================] - 11s 34ms/step - loss: 0.6032 - binary_accuracy: 0.7064 - val_loss: 0.5732 - val_binary_accuracy: 0.7232
# Training Accuracy: 0.725
# Validation Accuracy: 0.725

# %% [markdown]
# Result:
# - None: 80.4% vs. 77.4%
# - Dropout: 80.5% vs. 77.8% (Input=0.2, Layers=0.5)
# - Batch Normalization: led to extreme overfitting; 81.4% vs. 77.6% (with dropout)
# - Layer Normalization: 81.7% vs. 78.2% (first normalization, then dropout, no input dropout)
# - Gaussian Noise: 79.9% vs. 78.2% (incl. normalization + dropout)
# - L2: 72.5% vs. 72.5%
# -> i.e. a combination of Gaussian Noise + Layer Normalization + Dropout provided the best results

# %% [markdown]
# ##### Fine-Tune Optimization Algorithm:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D())
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Flatten())
  model.add(Dense(32, activation='relu', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=seed_value)))
  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 1000, 200)         126275400
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 1000, 64)          64064
# _________________________________________________________________
# average_pooling1d_52 (Averag (None, 500, 64)           0
# _________________________________________________________________
# gaussian_noise_61 (GaussianN (None, 500, 64)           0
# _________________________________________________________________
# layer_normalization_65 (Laye (None, 500, 64)           128
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 500, 64)           0
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 500, 64)           20544
# _________________________________________________________________
# average_pooling1d_53 (Averag (None, 250, 64)           0
# _________________________________________________________________
# gaussian_noise_62 (GaussianN (None, 250, 64)           0
# _________________________________________________________________
# layer_normalization_66 (Laye (None, 250, 64)           128
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 250, 64)           0
# _________________________________________________________________
# conv1d_54 (Conv1D)           (None, 250, 64)           20544
# _________________________________________________________________
# average_pooling1d_54 (Averag (None, 125, 64)           0
# _________________________________________________________________
# gaussian_noise_63 (GaussianN (None, 125, 64)           0
# _________________________________________________________________
# layer_normalization_67 (Laye (None, 125, 64)           128
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 125, 64)           0
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 125, 64)           20544
# _________________________________________________________________
# average_pooling1d_55 (Averag (None, 62, 64)            0
# _________________________________________________________________
# gaussian_noise_64 (GaussianN (None, 62, 64)            0
# _________________________________________________________________
# layer_normalization_68 (Laye (None, 62, 64)            128
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 62, 64)            0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 3968)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                127008
# _________________________________________________________________
# gaussian_noise_65 (GaussianN (None, 32)                0
# _________________________________________________________________
# layer_normalization_69 (Laye (None, 32)                64
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 126,528,713
# Trainable params: 253,313
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=10, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 169/169 [==============================] - 27s 94ms/step - loss: 0.7201 - binary_accuracy: 0.6028 - val_loss: 0.5533 - val_binary_accuracy: 0.7007
# Epoch 2/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5609 - binary_accuracy: 0.6988 - val_loss: 0.5332 - val_binary_accuracy: 0.7234
# Epoch 3/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5402 - binary_accuracy: 0.7202 - val_loss: 0.5233 - val_binary_accuracy: 0.7327
# Epoch 4/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5335 - binary_accuracy: 0.7275 - val_loss: 0.5096 - val_binary_accuracy: 0.7419
# Epoch 5/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5257 - binary_accuracy: 0.7345 - val_loss: 0.5089 - val_binary_accuracy: 0.7421
# Epoch 6/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5196 - binary_accuracy: 0.7387 - val_loss: 0.5213 - val_binary_accuracy: 0.7330
# Epoch 7/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5171 - binary_accuracy: 0.7410 - val_loss: 0.4981 - val_binary_accuracy: 0.7520
# Epoch 8/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5134 - binary_accuracy: 0.7451 - val_loss: 0.5052 - val_binary_accuracy: 0.7447
# Epoch 9/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.5035 - binary_accuracy: 0.7510 - val_loss: 0.5045 - val_binary_accuracy: 0.7438
# Epoch 10/100
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5035 - binary_accuracy: 0.7518 - val_loss: 0.4922 - val_binary_accuracy: 0.7533
# Epoch 11/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4997 - binary_accuracy: 0.7539 - val_loss: 0.4861 - val_binary_accuracy: 0.7595
# Epoch 12/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4953 - binary_accuracy: 0.7574 - val_loss: 0.4822 - val_binary_accuracy: 0.7609
# Epoch 13/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4933 - binary_accuracy: 0.7593 - val_loss: 0.4845 - val_binary_accuracy: 0.7594
# Epoch 14/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4926 - binary_accuracy: 0.7588 - val_loss: 0.4781 - val_binary_accuracy: 0.7655
# Epoch 15/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4903 - binary_accuracy: 0.7597 - val_loss: 0.4779 - val_binary_accuracy: 0.7647
# Epoch 16/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4895 - binary_accuracy: 0.7598 - val_loss: 0.4759 - val_binary_accuracy: 0.7657
# Epoch 17/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4844 - binary_accuracy: 0.7644 - val_loss: 0.4786 - val_binary_accuracy: 0.7635
# Epoch 18/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4867 - binary_accuracy: 0.7634 - val_loss: 0.5097 - val_binary_accuracy: 0.7503
# Epoch 19/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4847 - binary_accuracy: 0.7638 - val_loss: 0.4708 - val_binary_accuracy: 0.7700
# Epoch 20/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4801 - binary_accuracy: 0.7667 - val_loss: 0.4982 - val_binary_accuracy: 0.7510
# Epoch 21/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4795 - binary_accuracy: 0.7685 - val_loss: 0.4831 - val_binary_accuracy: 0.7620
# Epoch 22/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4788 - binary_accuracy: 0.7680 - val_loss: 0.4805 - val_binary_accuracy: 0.7628
# Epoch 23/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4745 - binary_accuracy: 0.7709 - val_loss: 0.4692 - val_binary_accuracy: 0.7709
# Epoch 24/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4773 - binary_accuracy: 0.7703 - val_loss: 0.4693 - val_binary_accuracy: 0.7698
# Epoch 25/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4726 - binary_accuracy: 0.7705 - val_loss: 0.4642 - val_binary_accuracy: 0.7740
# Epoch 26/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4713 - binary_accuracy: 0.7725 - val_loss: 0.4694 - val_binary_accuracy: 0.7715
# Epoch 27/100
# 169/169 [==============================] - 6s 39ms/step - loss: 0.4716 - binary_accuracy: 0.7736 - val_loss: 0.4654 - val_binary_accuracy: 0.7737
# Epoch 28/100
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4703 - binary_accuracy: 0.7747 - val_loss: 0.4802 - val_binary_accuracy: 0.7673
# Epoch 29/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4736 - binary_accuracy: 0.7717 - val_loss: 0.4653 - val_binary_accuracy: 0.7721
# Epoch 30/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4701 - binary_accuracy: 0.7744 - val_loss: 0.4660 - val_binary_accuracy: 0.7744
# Epoch 31/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4696 - binary_accuracy: 0.7728 - val_loss: 0.4647 - val_binary_accuracy: 0.7748
# Epoch 32/100
# 169/169 [==============================] - 7s 42ms/step - loss: 0.4662 - binary_accuracy: 0.7757 - val_loss: 0.4742 - val_binary_accuracy: 0.7725
# Epoch 33/100
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4644 - binary_accuracy: 0.7783 - val_loss: 0.4655 - val_binary_accuracy: 0.7729
# Epoch 34/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4642 - binary_accuracy: 0.7784 - val_loss: 0.4649 - val_binary_accuracy: 0.7724
# Epoch 35/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4630 - binary_accuracy: 0.7785 - val_loss: 0.4639 - val_binary_accuracy: 0.7742
# Epoch 36/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4615 - binary_accuracy: 0.7789 - val_loss: 0.4629 - val_binary_accuracy: 0.7755
# Epoch 37/100
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4622 - binary_accuracy: 0.7782 - val_loss: 0.4605 - val_binary_accuracy: 0.7763
# Epoch 38/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4616 - binary_accuracy: 0.7777 - val_loss: 0.4619 - val_binary_accuracy: 0.7767
# Epoch 39/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4610 - binary_accuracy: 0.7795 - val_loss: 0.4694 - val_binary_accuracy: 0.7690
# Epoch 40/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4574 - binary_accuracy: 0.7830 - val_loss: 0.4746 - val_binary_accuracy: 0.7682
# Epoch 41/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4599 - binary_accuracy: 0.7800 - val_loss: 0.4728 - val_binary_accuracy: 0.7689
# Epoch 42/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4568 - binary_accuracy: 0.7814 - val_loss: 0.4699 - val_binary_accuracy: 0.7693
# Epoch 43/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4583 - binary_accuracy: 0.7817 - val_loss: 0.4699 - val_binary_accuracy: 0.7730
# Epoch 44/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4561 - binary_accuracy: 0.7833 - val_loss: 0.4632 - val_binary_accuracy: 0.7759
# Epoch 45/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4556 - binary_accuracy: 0.7821 - val_loss: 0.4662 - val_binary_accuracy: 0.7750
# Epoch 46/100
# 169/169 [==============================] - 6s 38ms/step - loss: 0.4562 - binary_accuracy: 0.7832 - val_loss: 0.4672 - val_binary_accuracy: 0.7746
# Epoch 47/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4542 - binary_accuracy: 0.7832 - val_loss: 0.4746 - val_binary_accuracy: 0.7689
# Epoch 48/100
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4546 - binary_accuracy: 0.7823 - val_loss: 0.4708 - val_binary_accuracy: 0.7721
# Training Accuracy: 0.790
# Validation Accuracy: 0.777

# %% [markdown]
# Results:
# - RMSprop: 79.9% vs. 78.2%
# - RMSprop_centered: 79.1% vs. 78.1%
# - Adam: 80.1% vs. 78.2%
# - Adam_amsgrad: not supported with TPU
# - Adamax: 79.5% vs. 78.2% (but took extremely long)
# - Nadam: 79.8% vs. 78.3%
# -> i.e. Nadam provided the best results
# - GlorotUniform: 79.8% vs. 78.3%
# - GlorotNormal: 80.3% vs. 78.2%
# - HeUniform: 80.1% vs. 78.3%
# - HeNormal: 80.9% vs. 78.2%
# - LecunUniform: 80.8% vs. 78.3%
# - LecunNormal: 80% vs. 78.1%
# -> i.e. GlorotUniform provided the best results
# - But: differences were only marginal between all optimizers and initializers

# %% [markdown]
# ##### Try different types of CNN layers:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D())
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Flatten())
  model.add(Dense(32, activation='relu', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=seed_value)))
  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_16 (Embedding)     (None, 1000, 200)         126275400
# _________________________________________________________________
# locally_connected1d_1 (Local (None, 996, 64)           63807744
# _________________________________________________________________
# average_pooling1d_60 (Averag (None, 498, 64)           0
# _________________________________________________________________
# gaussian_noise_71 (GaussianN (None, 498, 64)           0
# _________________________________________________________________
# layer_normalization_75 (Laye (None, 498, 64)           128
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 498, 64)           0
# _________________________________________________________________
# locally_connected1d_2 (Local (None, 494, 64)           10148736
# _________________________________________________________________
# average_pooling1d_61 (Averag (None, 247, 64)           0
# _________________________________________________________________
# gaussian_noise_72 (GaussianN (None, 247, 64)           0
# _________________________________________________________________
# layer_normalization_76 (Laye (None, 247, 64)           128
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 247, 64)           0
# _________________________________________________________________
# locally_connected1d_3 (Local (None, 243, 64)           4992192
# _________________________________________________________________
# average_pooling1d_62 (Averag (None, 121, 64)           0
# _________________________________________________________________
# gaussian_noise_73 (GaussianN (None, 121, 64)           0
# _________________________________________________________________
# layer_normalization_77 (Laye (None, 121, 64)           128
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 121, 64)           0
# _________________________________________________________________
# locally_connected1d_4 (Local (None, 117, 64)           2403648
# _________________________________________________________________
# average_pooling1d_63 (Averag (None, 58, 64)            0
# _________________________________________________________________
# gaussian_noise_74 (GaussianN (None, 58, 64)            0
# _________________________________________________________________
# layer_normalization_78 (Laye (None, 58, 64)            128
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 58, 64)            0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 3712)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 32)                118816
# _________________________________________________________________
# gaussian_noise_75 (GaussianN (None, 32)                0
# _________________________________________________________________
# layer_normalization_79 (Laye (None, 32)                64
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 207,747,145
# Trainable params: 81,471,745
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=10, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))

# %% [markdown]
# Results:
# - CNN: 79.8% vs. 78.3%
# - Separable CNN: 80% vs. 78.1%
# - Locally-Connected CNN: overfits quite badly

# %% [markdown]
# #### d) Fine-Tune RNN Model

# %% [markdown]
# ##### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["title"] + " " + kickstarter_df["blurb"] + " " + kickstarter_df["story"] + " " + kickstarter_df["risks"] + " " + kickstarter_df["creator_bio"] + " " + kickstarter_df["reward_description"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()
# Out:
# 100%|██████████| 246891/246891 [00:43<00:00, 5664.08it/s]

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
import fasttext, fasttext.util
ft = fasttext.load_model('cc.en.300.bin')
print("Embedding Dimension: {}".format(ft.get_dimension()))
# Out:
# Embedding Dimension: 200
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Define parameters for text processing 
max_features = 631377
max_len = 1000
embedding_dim = 300

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(len(word_index)))
# Out:
# Included Token: 631377

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      509.529984
# std       409.239714
# min        14.000000
# 25%       241.000000
# 50%       399.000000
# 75%       649.000000
# max     11553.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 1000)
# Shape of X_val: (37034, 1000)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      embedding_vector = ft.get_word_vector(word)
      if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (631377, 300)
# Number of Null Word Embeddings: 218

# %% [markdown]
# ##### Test LSTM vs GRU:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(GRU(32, kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=RMSprop(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_20 (Embedding)     (None, 1000, 200)         126275400
# _________________________________________________________________
# gru (GRU)                    (None, 32)                22464
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 126,297,897
# Trainable params: 22,497
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=10, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 29s 73ms/step - loss: 0.6205 - binary_accuracy: 0.6550 - val_loss: 0.5700 - val_binary_accuracy: 0.6860
# Epoch 2/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.5688 - binary_accuracy: 0.6899 - val_loss: 0.5612 - val_binary_accuracy: 0.7090
# Epoch 3/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.5448 - binary_accuracy: 0.7172 - val_loss: 0.5262 - val_binary_accuracy: 0.7356
# Epoch 4/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.5261 - binary_accuracy: 0.7343 - val_loss: 0.5222 - val_binary_accuracy: 0.7351
# Epoch 5/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.5192 - binary_accuracy: 0.7374 - val_loss: 0.5119 - val_binary_accuracy: 0.7420
# Epoch 6/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.5113 - binary_accuracy: 0.7439 - val_loss: 0.5060 - val_binary_accuracy: 0.7490
# Epoch 7/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.5091 - binary_accuracy: 0.7444 - val_loss: 0.5048 - val_binary_accuracy: 0.7458
# Epoch 8/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.5047 - binary_accuracy: 0.7491 - val_loss: 0.5047 - val_binary_accuracy: 0.7478
# Epoch 9/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4958 - binary_accuracy: 0.7546 - val_loss: 0.5232 - val_binary_accuracy: 0.7312
# Epoch 10/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4948 - binary_accuracy: 0.7551 - val_loss: 0.5039 - val_binary_accuracy: 0.7466
# Epoch 11/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4900 - binary_accuracy: 0.7577 - val_loss: 0.4854 - val_binary_accuracy: 0.7597
# Epoch 12/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4871 - binary_accuracy: 0.7612 - val_loss: 0.4867 - val_binary_accuracy: 0.7586
# Epoch 13/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4843 - binary_accuracy: 0.7621 - val_loss: 0.4885 - val_binary_accuracy: 0.7585
# Epoch 14/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4826 - binary_accuracy: 0.7629 - val_loss: 0.4830 - val_binary_accuracy: 0.7603
# Epoch 15/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4788 - binary_accuracy: 0.7650 - val_loss: 0.5005 - val_binary_accuracy: 0.7496
# Epoch 16/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4785 - binary_accuracy: 0.7656 - val_loss: 0.4761 - val_binary_accuracy: 0.7658
# Epoch 17/100
# 338/338 [==============================] - 20s 58ms/step - loss: 0.4743 - binary_accuracy: 0.7683 - val_loss: 0.4772 - val_binary_accuracy: 0.7646
# Epoch 18/100
# 338/338 [==============================] - 20s 58ms/step - loss: 0.4757 - binary_accuracy: 0.7680 - val_loss: 0.4765 - val_binary_accuracy: 0.7661
# Epoch 19/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4722 - binary_accuracy: 0.7702 - val_loss: 0.4731 - val_binary_accuracy: 0.7691
# Epoch 20/100
# 338/338 [==============================] - 19s 58ms/step - loss: 0.4672 - binary_accuracy: 0.7734 - val_loss: 0.4768 - val_binary_accuracy: 0.7658
# Epoch 21/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4675 - binary_accuracy: 0.7732 - val_loss: 0.4715 - val_binary_accuracy: 0.7689
# Epoch 22/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4666 - binary_accuracy: 0.7739 - val_loss: 0.5001 - val_binary_accuracy: 0.7452
# Epoch 23/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4627 - binary_accuracy: 0.7759 - val_loss: 0.4688 - val_binary_accuracy: 0.7705
# Epoch 24/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4632 - binary_accuracy: 0.7756 - val_loss: 0.4769 - val_binary_accuracy: 0.7648
# Epoch 25/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4607 - binary_accuracy: 0.7768 - val_loss: 0.4768 - val_binary_accuracy: 0.7653
# Epoch 26/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4599 - binary_accuracy: 0.7776 - val_loss: 0.4752 - val_binary_accuracy: 0.7677
# Epoch 27/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4587 - binary_accuracy: 0.7783 - val_loss: 0.4746 - val_binary_accuracy: 0.7654
# Epoch 28/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4569 - binary_accuracy: 0.7797 - val_loss: 0.4660 - val_binary_accuracy: 0.7733
# Epoch 29/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4584 - binary_accuracy: 0.7794 - val_loss: 0.4645 - val_binary_accuracy: 0.7724
# Epoch 30/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4555 - binary_accuracy: 0.7802 - val_loss: 0.4640 - val_binary_accuracy: 0.7745
# Epoch 31/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4557 - binary_accuracy: 0.7786 - val_loss: 0.4647 - val_binary_accuracy: 0.7754
# Epoch 32/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4525 - binary_accuracy: 0.7822 - val_loss: 0.4633 - val_binary_accuracy: 0.7742
# Epoch 33/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4484 - binary_accuracy: 0.7857 - val_loss: 0.4628 - val_binary_accuracy: 0.7734
# Epoch 34/100
# 338/338 [==============================] - 19s 58ms/step - loss: 0.4496 - binary_accuracy: 0.7849 - val_loss: 0.4656 - val_binary_accuracy: 0.7742
# Epoch 35/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4490 - binary_accuracy: 0.7846 - val_loss: 0.4644 - val_binary_accuracy: 0.7768
# Epoch 36/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4458 - binary_accuracy: 0.7867 - val_loss: 0.4623 - val_binary_accuracy: 0.7756
# Epoch 37/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4473 - binary_accuracy: 0.7851 - val_loss: 0.4699 - val_binary_accuracy: 0.7695
# Epoch 38/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4459 - binary_accuracy: 0.7871 - val_loss: 0.4594 - val_binary_accuracy: 0.7764
# Epoch 39/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4450 - binary_accuracy: 0.7882 - val_loss: 0.4613 - val_binary_accuracy: 0.7746
# Epoch 40/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4422 - binary_accuracy: 0.7898 - val_loss: 0.4682 - val_binary_accuracy: 0.7743
# Epoch 41/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4432 - binary_accuracy: 0.7887 - val_loss: 0.4592 - val_binary_accuracy: 0.7775
# Epoch 42/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4397 - binary_accuracy: 0.7900 - val_loss: 0.4603 - val_binary_accuracy: 0.7756
# Epoch 43/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4473 - binary_accuracy: 0.7874 - val_loss: 0.4633 - val_binary_accuracy: 0.7741
# Epoch 44/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4391 - binary_accuracy: 0.7920 - val_loss: 0.4611 - val_binary_accuracy: 0.7765
# Epoch 45/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4380 - binary_accuracy: 0.7918 - val_loss: 0.4650 - val_binary_accuracy: 0.7757
# Epoch 46/100
# 338/338 [==============================] - 19s 56ms/step - loss: 0.4396 - binary_accuracy: 0.7917 - val_loss: 0.4695 - val_binary_accuracy: 0.7723
# Epoch 47/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4367 - binary_accuracy: 0.7938 - val_loss: 0.4746 - val_binary_accuracy: 0.7712
# Epoch 48/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4359 - binary_accuracy: 0.7934 - val_loss: 0.4697 - val_binary_accuracy: 0.7725
# Epoch 49/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4370 - binary_accuracy: 0.7931 - val_loss: 0.4600 - val_binary_accuracy: 0.7774
# Epoch 50/100
# 338/338 [==============================] - 20s 58ms/step - loss: 0.4370 - binary_accuracy: 0.7927 - val_loss: 0.4646 - val_binary_accuracy: 0.7769
# Epoch 51/100
# 338/338 [==============================] - 19s 57ms/step - loss: 0.4372 - binary_accuracy: 0.7932 - val_loss: 0.4715 - val_binary_accuracy: 0.7727
# Training Accuracy: 0.793
# Validation Accuracy: 0.777

# %% [markdown]
# Result:
# - LSTM: 79.1% vs. 77.3%
# - GRU: 79.3% vs. 77.7%
# -> i.e. GRU was better and converged faster

# %% [markdown]
# ##### Test Regularization Techniques Before Dense Layer and After Input Layer:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, embeddings_initializer=Constant(embedding_matrix), input_length=max_len, trainable=False))
  model.add(GaussianNoise(stddev=0.1))
  model.add(GRU(64, kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 1000, 200)         126275400
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1000, 200)         0
# _________________________________________________________________
# gru_12 (GRU)                 (None, 64)                51072
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 126,326,537
# Trainable params: 51,137
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=10, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))

# %% [markdown]
# Results:
# - Dropout in RNN = takes too long to train
# - Dropout Before Dense = 80% vs. 78.2% (Dense=0.5)
# - Dropout Before Dense + After Input: 80.5% vs. 78.3%; but took longer to train (Input=0.2, Dense=0.5)
# - Batch Normalization Before Dense: was not useful; accuracy jumped around
# - Layer Normalization Before Dense: 79.1% vs. 77.6%
# - Layer Normalization + Dropout Before Dense: 79.9% vs. 78.1%
# - Gaussian Noise Before Dense: 79.2% vs. 78%
# -> i.e. adding only dropout provided the best results; maybe now it is possible to increase the capacity of the network

# %% [markdown]
# ##### Fine-Tune Network Architecture:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, embeddings_initializer=Constant(embedding_matrix), input_length=max_len, trainable=False))
  model.add(Bidirectional(GRU(64, kernel_initializer=GlorotUniform(seed=seed_value))))
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"], steps_per_execution=100)

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_35 (Embedding)     (None, 1000, 200)         126275400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               102144
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 126,377,673
# Trainable params: 102,273
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 41s 120ms/step - loss: 0.6251 - binary_accuracy: 0.6573 - val_loss: 0.5656 - val_binary_accuracy: 0.6889
# Epoch 2/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.5488 - binary_accuracy: 0.7144 - val_loss: 0.5415 - val_binary_accuracy: 0.7157
# Epoch 3/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.5197 - binary_accuracy: 0.7392 - val_loss: 0.5062 - val_binary_accuracy: 0.7462
# Epoch 4/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.5123 - binary_accuracy: 0.7459 - val_loss: 0.5007 - val_binary_accuracy: 0.7520
# Epoch 5/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.5068 - binary_accuracy: 0.7477 - val_loss: 0.4984 - val_binary_accuracy: 0.7543
# Epoch 6/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4992 - binary_accuracy: 0.7554 - val_loss: 0.5090 - val_binary_accuracy: 0.7531
# Epoch 7/100
# 338/338 [==============================] - 22s 66ms/step - loss: 0.4966 - binary_accuracy: 0.7554 - val_loss: 0.4921 - val_binary_accuracy: 0.7554
# Epoch 8/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4904 - binary_accuracy: 0.7595 - val_loss: 0.4847 - val_binary_accuracy: 0.7613
# Epoch 9/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4837 - binary_accuracy: 0.7638 - val_loss: 0.4974 - val_binary_accuracy: 0.7514
# Epoch 10/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4822 - binary_accuracy: 0.7647 - val_loss: 0.4904 - val_binary_accuracy: 0.7554
# Epoch 11/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4781 - binary_accuracy: 0.7680 - val_loss: 0.4809 - val_binary_accuracy: 0.7633
# Epoch 12/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4753 - binary_accuracy: 0.7699 - val_loss: 0.4780 - val_binary_accuracy: 0.7651
# Epoch 13/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4707 - binary_accuracy: 0.7726 - val_loss: 0.4788 - val_binary_accuracy: 0.7648
# Epoch 14/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4682 - binary_accuracy: 0.7732 - val_loss: 0.4726 - val_binary_accuracy: 0.7696
# Epoch 15/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4651 - binary_accuracy: 0.7750 - val_loss: 0.4732 - val_binary_accuracy: 0.7681
# Epoch 16/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4615 - binary_accuracy: 0.7778 - val_loss: 0.4681 - val_binary_accuracy: 0.7725
# Epoch 17/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4582 - binary_accuracy: 0.7808 - val_loss: 0.4715 - val_binary_accuracy: 0.7692
# Epoch 18/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4567 - binary_accuracy: 0.7816 - val_loss: 0.4707 - val_binary_accuracy: 0.7713
# Epoch 19/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4548 - binary_accuracy: 0.7827 - val_loss: 0.4678 - val_binary_accuracy: 0.7731
# Epoch 20/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4489 - binary_accuracy: 0.7857 - val_loss: 0.4688 - val_binary_accuracy: 0.7727
# Epoch 21/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4478 - binary_accuracy: 0.7864 - val_loss: 0.4703 - val_binary_accuracy: 0.7736
# Epoch 22/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4448 - binary_accuracy: 0.7882 - val_loss: 0.4861 - val_binary_accuracy: 0.7623
# Epoch 23/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4411 - binary_accuracy: 0.7909 - val_loss: 0.4698 - val_binary_accuracy: 0.7728
# Epoch 24/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4387 - binary_accuracy: 0.7922 - val_loss: 0.4676 - val_binary_accuracy: 0.7749
# Epoch 25/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4352 - binary_accuracy: 0.7932 - val_loss: 0.4823 - val_binary_accuracy: 0.7675
# Epoch 26/100
# 338/338 [==============================] - 22s 66ms/step - loss: 0.4328 - binary_accuracy: 0.7964 - val_loss: 0.4801 - val_binary_accuracy: 0.7753
# Epoch 27/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4296 - binary_accuracy: 0.7982 - val_loss: 0.4716 - val_binary_accuracy: 0.7737
# Epoch 28/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4285 - binary_accuracy: 0.7982 - val_loss: 0.4745 - val_binary_accuracy: 0.7762
# Epoch 29/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4262 - binary_accuracy: 0.7994 - val_loss: 0.4758 - val_binary_accuracy: 0.7747
# Epoch 30/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4213 - binary_accuracy: 0.8026 - val_loss: 0.4801 - val_binary_accuracy: 0.7726
# Epoch 31/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4185 - binary_accuracy: 0.8031 - val_loss: 0.4912 - val_binary_accuracy: 0.7670
# Epoch 32/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4137 - binary_accuracy: 0.8063 - val_loss: 0.4864 - val_binary_accuracy: 0.7705
# Epoch 33/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4118 - binary_accuracy: 0.8088 - val_loss: 0.4852 - val_binary_accuracy: 0.7724
# Epoch 34/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4079 - binary_accuracy: 0.8097 - val_loss: 0.4888 - val_binary_accuracy: 0.7730
# Epoch 35/100
# 338/338 [==============================] - 22s 65ms/step - loss: 0.4048 - binary_accuracy: 0.8117 - val_loss: 0.5034 - val_binary_accuracy: 0.7706
# Training Accuracy: 0.805
# Validation Accuracy: 0.776

# %% [markdown]
# Results:
# - 512 Units: 79.2% vs. 77.5%
# - 256 Units: 81.6% vs. 77.7%
# - 128 Units: 80.5% vs. 78%
# - 64 Units: 80% vs. 78.2%
# - 32 Units: 79.9% vs. 78%
# - 2 Layers, 32 Units: 79.2% vs. 77.9%
# - 2 Layers, 64 Units: 79.8% vs. 77.8%
# - Bidirectional 64 Units: 80.5% vs. 77.6%
# -> i.e. 1 Layer, 64 Units is the best

# %% [markdown]
# ##### Test Recurrent Dropout:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, embeddings_initializer=Constant(embedding_matrix), input_length=max_len, trainable=False))
  model.add(GRU(256, kernel_initializer=GlorotUniform(seed=seed_value), dropout=0.5, recurrent_dropout=0.5))
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(clipnorm=1.0), loss="binary_crossentropy", metrics=["binary_accuracy"], steps_per_execution=338)

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 200)         126275400
# _________________________________________________________________
# gru (GRU)                    (None, 256)               351744
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 126,627,401
# Trainable params: 352,001
# Non-trainable params: 126,275,400
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 50s 147ms/step - loss: 0.6295 - binary_accuracy: 0.6585 - val_loss: 0.6033 - val_binary_accuracy: 0.7090
# Epoch 2/100
# 338/338 [==============================] - 32s 96ms/step - loss: 0.5466 - binary_accuracy: 0.7169 - val_loss: 0.5633 - val_binary_accuracy: 0.6992
# Epoch 3/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.5279 - binary_accuracy: 0.7318 - val_loss: 0.5099 - val_binary_accuracy: 0.7430
# Epoch 4/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.5186 - binary_accuracy: 0.7378 - val_loss: 0.5005 - val_binary_accuracy: 0.7495
# Epoch 5/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.5115 - binary_accuracy: 0.7433 - val_loss: 0.4955 - val_binary_accuracy: 0.7528
# Epoch 6/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.5049 - binary_accuracy: 0.7480 - val_loss: 0.4998 - val_binary_accuracy: 0.7494
# Epoch 7/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.5016 - binary_accuracy: 0.7502 - val_loss: 0.4910 - val_binary_accuracy: 0.7547
# Epoch 8/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4962 - binary_accuracy: 0.7547 - val_loss: 0.4841 - val_binary_accuracy: 0.7592
# Epoch 9/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4908 - binary_accuracy: 0.7578 - val_loss: 0.5172 - val_binary_accuracy: 0.7337
# Epoch 10/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4863 - binary_accuracy: 0.7608 - val_loss: 0.4926 - val_binary_accuracy: 0.7529
# Epoch 11/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4836 - binary_accuracy: 0.7645 - val_loss: 0.4722 - val_binary_accuracy: 0.7694
# Epoch 12/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4793 - binary_accuracy: 0.7668 - val_loss: 0.4919 - val_binary_accuracy: 0.7516
# Epoch 13/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4767 - binary_accuracy: 0.7687 - val_loss: 0.4692 - val_binary_accuracy: 0.7732
# Epoch 14/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4739 - binary_accuracy: 0.7704 - val_loss: 0.4719 - val_binary_accuracy: 0.7685
# Epoch 15/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4709 - binary_accuracy: 0.7719 - val_loss: 0.4642 - val_binary_accuracy: 0.7775
# Epoch 16/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4682 - binary_accuracy: 0.7733 - val_loss: 0.4619 - val_binary_accuracy: 0.7763
# Epoch 17/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4661 - binary_accuracy: 0.7757 - val_loss: 0.4602 - val_binary_accuracy: 0.7779
# Epoch 18/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4634 - binary_accuracy: 0.7773 - val_loss: 0.4628 - val_binary_accuracy: 0.7783
# Epoch 19/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4609 - binary_accuracy: 0.7785 - val_loss: 0.4605 - val_binary_accuracy: 0.7779
# Epoch 20/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4592 - binary_accuracy: 0.7800 - val_loss: 0.4587 - val_binary_accuracy: 0.7800
# Epoch 21/100
# 338/338 [==============================] - 33s 96ms/step - loss: 0.4573 - binary_accuracy: 0.7814 - val_loss: 0.4579 - val_binary_accuracy: 0.7787
# Epoch 22/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4550 - binary_accuracy: 0.7823 - val_loss: 0.4698 - val_binary_accuracy: 0.7697
# Epoch 23/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4536 - binary_accuracy: 0.7836 - val_loss: 0.4546 - val_binary_accuracy: 0.7814
# Epoch 24/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4523 - binary_accuracy: 0.7840 - val_loss: 0.4537 - val_binary_accuracy: 0.7817
# Epoch 25/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4504 - binary_accuracy: 0.7857 - val_loss: 0.4607 - val_binary_accuracy: 0.7798
# Epoch 26/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4481 - binary_accuracy: 0.7873 - val_loss: 0.4559 - val_binary_accuracy: 0.7825
# Epoch 27/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4467 - binary_accuracy: 0.7885 - val_loss: 0.4506 - val_binary_accuracy: 0.7826
# Epoch 28/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4450 - binary_accuracy: 0.7890 - val_loss: 0.4521 - val_binary_accuracy: 0.7848
# Epoch 29/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4424 - binary_accuracy: 0.7915 - val_loss: 0.4495 - val_binary_accuracy: 0.7842
# Epoch 30/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4414 - binary_accuracy: 0.7913 - val_loss: 0.4501 - val_binary_accuracy: 0.7848
# Epoch 31/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4403 - binary_accuracy: 0.7919 - val_loss: 0.4586 - val_binary_accuracy: 0.7804
# Epoch 32/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4375 - binary_accuracy: 0.7935 - val_loss: 0.4520 - val_binary_accuracy: 0.7841
# Epoch 33/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4361 - binary_accuracy: 0.7937 - val_loss: 0.4480 - val_binary_accuracy: 0.7872
# Epoch 34/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4346 - binary_accuracy: 0.7949 - val_loss: 0.4480 - val_binary_accuracy: 0.7868
# Epoch 35/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4337 - binary_accuracy: 0.7964 - val_loss: 0.4602 - val_binary_accuracy: 0.7847
# Epoch 36/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4327 - binary_accuracy: 0.7972 - val_loss: 0.4480 - val_binary_accuracy: 0.7881
# Epoch 37/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4314 - binary_accuracy: 0.7967 - val_loss: 0.4488 - val_binary_accuracy: 0.7839
# Epoch 38/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4288 - binary_accuracy: 0.7989 - val_loss: 0.4466 - val_binary_accuracy: 0.7871
# Epoch 39/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4273 - binary_accuracy: 0.7996 - val_loss: 0.4486 - val_binary_accuracy: 0.7872
# Epoch 40/100
# 338/338 [==============================] - 32s 96ms/step - loss: 0.4263 - binary_accuracy: 0.8005 - val_loss: 0.4516 - val_binary_accuracy: 0.7851
# Epoch 41/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4247 - binary_accuracy: 0.8008 - val_loss: 0.4504 - val_binary_accuracy: 0.7856
# Epoch 42/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4238 - binary_accuracy: 0.8016 - val_loss: 0.4459 - val_binary_accuracy: 0.7864
# Epoch 43/100
# 338/338 [==============================] - 32s 95ms/step - loss: 0.4222 - binary_accuracy: 0.8024 - val_loss: 0.4506 - val_binary_accuracy: 0.7872
# Training Accuracy: 0.809
# Validation Accuracy: 0.788

# %% [markdown]
# Results:
# - dropout=0.5, recurrent_dropout=0.5, 32 Units: underfits too much
# - dropout=0.5, recurrent_dropout=0.5, 64 Units: 80.3% vs. 78.6%
# - dropout=0.5, recurrent_dropout=0.5, 128 Units: 79.9% vs. 78.4%
# - dropout=0.5, recurrent_dropout=0.5, 256 Units: 82.2% vs. 78.8%
# - dropout=0.5, recurrent_dropout=0.5, 512 Units: jumps around to heavily
# - dropout=0.5, recurrent_dropout=0.5, 64 Units, 2 Layers: 80.3% vs. 78.7%
# - dropout=0.5, recurrent_dropout=0.5, 256 Units, 2 Layers: 82.1% vs. 78.8%
# - dropout=0.5, recurrent_dropout=0.5, 64 Units, 3 Layers: 80.2% vs. 78.7%
# -> i.e. dropout + 1 layer + 256 units provided the best results
# -> adding additional layers did not help to improve performance
# - dropout=0.3, recurrent_dropout=0.3, 64 Units: 79.4% vs. 78.4%
# - dropout=0.3, recurrent_dropout=0.3, 256 Units: 80.4% vs.78.4%
# -> i.e. a high dropout of 0.5 provided the best results
# - dropout=0.5, recurrent_dropout=0.5, dense_dropout=0.5, 256 Units: 81.4% vs. 78.8%
# -> i.e. adding Dense dropout helps a little bit to reduce overfitting
# - dropout=0.5, recurrent_dropout=0.5, dense_dropout=0.5, 256 Units; gradient-clipping: 80.9% vs. 78.8%
# -> i.e. gradient clipping further reduced the overfitting effect

# %% [markdown]
# ##### Re-try 300-dimensional embeddings with the regularized network:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, embeddings_initializer=Constant(embedding_matrix), input_length=max_len, trainable=False))
  model.add(GRU(256, kernel_initializer=GlorotUniform(seed=seed_value), dropout=0.5, recurrent_dropout=0.5))
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(clipnorm=1.0), loss="binary_crossentropy", metrics=["binary_accuracy"], steps_per_execution=338)

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 1000, 300)         189413100
# _________________________________________________________________
# gru_1 (GRU)                  (None, 256)               428544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 189,841,901
# Trainable params: 428,801
# Non-trainable params: 189,413,100
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# 338/338 [==============================] - 56s 164ms/step - loss: 0.6206 - binary_accuracy: 0.6597 - val_loss: 0.6063 - val_binary_accuracy: 0.6621
# Epoch 2/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5427 - binary_accuracy: 0.7203 - val_loss: 0.5397 - val_binary_accuracy: 0.7083
# Epoch 3/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5220 - binary_accuracy: 0.7353 - val_loss: 0.5046 - val_binary_accuracy: 0.7487
# Epoch 4/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5123 - binary_accuracy: 0.7430 - val_loss: 0.4958 - val_binary_accuracy: 0.7541
# Epoch 5/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5043 - binary_accuracy: 0.7487 - val_loss: 0.4901 - val_binary_accuracy: 0.7582
# Epoch 6/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4972 - binary_accuracy: 0.7536 - val_loss: 0.4897 - val_binary_accuracy: 0.7572
# Epoch 7/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4916 - binary_accuracy: 0.7571 - val_loss: 0.4825 - val_binary_accuracy: 0.7631
# Epoch 8/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4867 - binary_accuracy: 0.7601 - val_loss: 0.4741 - val_binary_accuracy: 0.7688
# Epoch 9/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4819 - binary_accuracy: 0.7640 - val_loss: 0.4874 - val_binary_accuracy: 0.7557
# Epoch 10/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4770 - binary_accuracy: 0.7676 - val_loss: 0.4880 - val_binary_accuracy: 0.7604
# Epoch 11/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4736 - binary_accuracy: 0.7694 - val_loss: 0.4645 - val_binary_accuracy: 0.7751
# Epoch 12/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4701 - binary_accuracy: 0.7720 - val_loss: 0.4719 - val_binary_accuracy: 0.7691
# Epoch 13/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4673 - binary_accuracy: 0.7740 - val_loss: 0.4627 - val_binary_accuracy: 0.7765
# Epoch 14/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4641 - binary_accuracy: 0.7772 - val_loss: 0.4644 - val_binary_accuracy: 0.7749
# Epoch 15/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4604 - binary_accuracy: 0.7783 - val_loss: 0.4579 - val_binary_accuracy: 0.7806
# Epoch 16/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4589 - binary_accuracy: 0.7795 - val_loss: 0.4550 - val_binary_accuracy: 0.7817
# Epoch 17/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4550 - binary_accuracy: 0.7815 - val_loss: 0.4549 - val_binary_accuracy: 0.7817
# Epoch 18/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4530 - binary_accuracy: 0.7843 - val_loss: 0.4541 - val_binary_accuracy: 0.7827
# Epoch 19/100
# 338/338 [==============================] - 36s 107ms/step - loss: 0.4510 - binary_accuracy: 0.7845 - val_loss: 0.4534 - val_binary_accuracy: 0.7825
# Epoch 20/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4488 - binary_accuracy: 0.7858 - val_loss: 0.4544 - val_binary_accuracy: 0.7816
# Epoch 21/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4468 - binary_accuracy: 0.7873 - val_loss: 0.4529 - val_binary_accuracy: 0.7828
# Epoch 22/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4436 - binary_accuracy: 0.7891 - val_loss: 0.4669 - val_binary_accuracy: 0.7780
# Epoch 23/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4424 - binary_accuracy: 0.7900 - val_loss: 0.4512 - val_binary_accuracy: 0.7834
# Epoch 24/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4407 - binary_accuracy: 0.7916 - val_loss: 0.4496 - val_binary_accuracy: 0.7827
# Epoch 25/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4385 - binary_accuracy: 0.7925 - val_loss: 0.4526 - val_binary_accuracy: 0.7836
# Epoch 26/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4357 - binary_accuracy: 0.7949 - val_loss: 0.4535 - val_binary_accuracy: 0.7864
# Epoch 27/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4355 - binary_accuracy: 0.7943 - val_loss: 0.4466 - val_binary_accuracy: 0.7867
# Epoch 28/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4329 - binary_accuracy: 0.7961 - val_loss: 0.4483 - val_binary_accuracy: 0.7865
# Epoch 29/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4310 - binary_accuracy: 0.7973 - val_loss: 0.4465 - val_binary_accuracy: 0.7868
# Epoch 30/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4292 - binary_accuracy: 0.7981 - val_loss: 0.4479 - val_binary_accuracy: 0.7850
# Epoch 31/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4282 - binary_accuracy: 0.8000 - val_loss: 0.4560 - val_binary_accuracy: 0.7813
# Epoch 32/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4266 - binary_accuracy: 0.7997 - val_loss: 0.4476 - val_binary_accuracy: 0.7848
# Epoch 33/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4249 - binary_accuracy: 0.8007 - val_loss: 0.4508 - val_binary_accuracy: 0.7834
# Epoch 34/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4236 - binary_accuracy: 0.8008 - val_loss: 0.4485 - val_binary_accuracy: 0.7888
# Epoch 35/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4218 - binary_accuracy: 0.8028 - val_loss: 0.4578 - val_binary_accuracy: 0.7861
# Epoch 36/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4210 - binary_accuracy: 0.8033 - val_loss: 0.4468 - val_binary_accuracy: 0.7858
# Epoch 37/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4199 - binary_accuracy: 0.8033 - val_loss: 0.4473 - val_binary_accuracy: 0.7844
# Epoch 38/100
# 338/338 [==============================] - 36s 107ms/step - loss: 0.4179 - binary_accuracy: 0.8052 - val_loss: 0.4484 - val_binary_accuracy: 0.7844
# Epoch 39/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4172 - binary_accuracy: 0.8057 - val_loss: 0.4485 - val_binary_accuracy: 0.7860
# Epoch 40/100
# 338/338 [==============================] - 36s 106ms/step - loss: 0.4154 - binary_accuracy: 0.8070 - val_loss: 0.4509 - val_binary_accuracy: 0.7867
# Epoch 41/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4149 - binary_accuracy: 0.8072 - val_loss: 0.4481 - val_binary_accuracy: 0.7875
# Training Accuracy: 0.819
# Validation Accuracy: 0.789

# %% [markdown]
# Result:
# - 81.9% vs. 78.9%
# -> i.e. using 300-dimensional embeddings minimally increased model performance
# -> since 300-dimensional embeddings also worked better with CNNs, switch back again to 300 dimensions

# %% [markdown]
# #### e) Try Using different embeddings

# %% [markdown]
# ##### Data Preparation:

# %%
# Extract Target Variable From Dataset
y = kickstarter_df["campaign_successful"].to_numpy()
text = kickstarter_df["title"] + " " + kickstarter_df["blurb"] + " " + kickstarter_df["story"] + " " + kickstarter_df["risks"] + " " + kickstarter_df["creator_bio"] + " " + kickstarter_df["reward_description"]

print(type(y))
print(y.shape)
print(type(text))
print(len(text))
# Out:
# <class 'numpy.ndarray'>
# (246891,)
# <class 'pandas.core.series.Series'>
# 246891

# %%
# Remove stopwords and punctation
stopwords = set(list(ENGLISH_STOP_WORDS) + ["s"])
text = text.str.replace(r"\.", "")
text = text.progress_apply(lambda x: " ".join([token for token in x.split() if token not in stopwords]))
text = text.to_numpy()

# %%
# Split dataset into training, subtraining, validation, and test set
train_size = round(kickstarter_df.shape[0]*0.7*1)
val_size = round(kickstarter_df.shape[0]*0.15*1)
test_size = round(kickstarter_df.shape[0]*1) - val_size - train_size

text_train, text_test, y_train, y_test = train_test_split(text, y, train_size=(train_size+val_size),test_size=test_size, shuffle=True, stratify=y, random_state=seed_value)
text_subtrain, text_val, y_subtrain, y_val = train_test_split(text_train, y_train, train_size=train_size, test_size=val_size, shuffle=True, stratify=y_train, random_state=seed_value)

print("Shape of X_train: {}".format(len(text_train)))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of X_subtrain: {}".format(len(text_subtrain)))
print("Shape of y_subtrain: {}".format(y_subtrain.shape))
print("Shape of X_val: {}".format(len(text_val)))
print("Shape of y_val: {}".format(y_val.shape))
print("Shape of X_test: {}".format(len(text_test)))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of X_train: 209858
# Shape of y_train: (209858,)
# Shape of X_subtrain: 172824
# Shape of y_subtrain: (172824,)
# Shape of X_val: 37034
# Shape of y_val: (37034,)
# Shape of X_test: 37033
# Shape of y_test: (37033,)

# %%
# Download word embeddings
import gensim.downloader as api
glove = api.load("glove-twitter-200")

# %%
# Define parameters for text processing 
max_features = 100000
max_len = 1000
embedding_dim = 200

# %%
# Convert Texts Into Integer Sequences (Tokenization)
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(text_subtrain)
X_subtrain = tokenizer.texts_to_sequences(text_subtrain)
X_val = tokenizer.texts_to_sequences(text_val)
word_index = tokenizer.word_index
print("Included Token: {}".format(tokenizer.num_words))
# Out:
# Included Token: 100000

# %%
# Determine number of words for max_len
num_words = pd.DataFrame([len(x) for x in X_subtrain])
num_words.rename(columns={0:"words"}, inplace=True)
num_words.describe()
# Out:
#                words
# count  172824.000000
# mean      502.025529
# std       402.349536
# min        14.000000
# 25%       237.000000
# 50%       393.000000
# 75%       640.000000
# max     11478.000000

# %%
# Pad and Truncate sequences
X_subtrain = pad_sequences(X_subtrain, maxlen=max_len, padding="pre", truncating="post")
X_val = pad_sequences(X_val, maxlen=max_len, padding="pre", truncating="post")

print("Shape of X_subtrain: {}".format(X_subtrain.shape))
print("Shape of X_val: {}".format(X_val.shape))
# Out:
# Shape of X_subtrain: (172824, 1000)
# Shape of X_val: (37034, 1000)

# %%
# Prepare the Embedding Matrix
print('Preparing Embedding Matrix...')
words_not_found = []
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, i in word_index.items():
    if i < max_features:
      if word in glove.vocab:
        embedding_matrix[i] = glove.get_vector(word)
      else:
        words_not_found.append(word)
print('Shape of Embedding Matrix: {}'.format(embedding_matrix.shape))
print('Number of Null Word Embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparing Embedding Matrix...
# Shape of Embedding Matrix: (100000, 300)
# Number of Null Word Embeddings: 41096

# %% [markdown]
# ##### CNN:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=False))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D(2))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Conv1D(64, 5, activation='relu', padding='same', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(AvgPool1D())
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Flatten())
  model.add(Dense(32, activation='relu', kernel_initializer=GlorotUniform(seed=seed_value)))
  model.add(GaussianNoise(stddev=0.1))
  model.add(LayerNormalization())
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=seed_value)))
  return model

# %%
# Compile the model
with strategy.scope():
  model = create_model()
  model.compile(optimizer=Nadam(), loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_26 (Embedding)     (None, 1000, 300)         30000000
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 1000, 64)          96064
# _________________________________________________________________
# average_pooling1d_27 (Averag (None, 500, 64)           0
# _________________________________________________________________
# gaussian_noise_27 (GaussianN (None, 500, 64)           0
# _________________________________________________________________
# layer_normalization_29 (Laye (None, 500, 64)           128
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 500, 64)           0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 500, 64)           20544
# _________________________________________________________________
# average_pooling1d_28 (Averag (None, 250, 64)           0
# _________________________________________________________________
# gaussian_noise_28 (GaussianN (None, 250, 64)           0
# _________________________________________________________________
# layer_normalization_30 (Laye (None, 250, 64)           128
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 250, 64)           0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 250, 64)           20544
# _________________________________________________________________
# average_pooling1d_29 (Averag (None, 125, 64)           0
# _________________________________________________________________
# gaussian_noise_29 (GaussianN (None, 125, 64)           0
# _________________________________________________________________
# layer_normalization_31 (Laye (None, 125, 64)           128
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 125, 64)           0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 125, 64)           20544
# _________________________________________________________________
# average_pooling1d_30 (Averag (None, 62, 64)            0
# _________________________________________________________________
# gaussian_noise_30 (GaussianN (None, 62, 64)            0
# _________________________________________________________________
# layer_normalization_32 (Laye (None, 62, 64)            128
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 62, 64)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3968)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                127008
# _________________________________________________________________
# gaussian_noise_31 (GaussianN (None, 32)                0
# _________________________________________________________________
# layer_normalization_33 (Laye (None, 32)                64
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 30,285,313
# Trainable params: 285,313
# Non-trainable params: 30,000,000
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 32s 61ms/step - loss: 0.6690 - binary_accuracy: 0.6314 - val_loss: 0.5400 - val_binary_accuracy: 0.7193
# Epoch 2/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.5441 - binary_accuracy: 0.7163 - val_loss: 0.5566 - val_binary_accuracy: 0.6946
# Epoch 3/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.5266 - binary_accuracy: 0.7328 - val_loss: 0.5050 - val_binary_accuracy: 0.7459
# Epoch 4/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.5175 - binary_accuracy: 0.7420 - val_loss: 0.5067 - val_binary_accuracy: 0.7493
# Epoch 5/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.5098 - binary_accuracy: 0.7470 - val_loss: 0.4955 - val_binary_accuracy: 0.7551
# Epoch 6/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4993 - binary_accuracy: 0.7534 - val_loss: 0.4959 - val_binary_accuracy: 0.7534
# Epoch 7/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4964 - binary_accuracy: 0.7565 - val_loss: 0.4944 - val_binary_accuracy: 0.7526
# Epoch 8/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4901 - binary_accuracy: 0.7599 - val_loss: 0.4728 - val_binary_accuracy: 0.7701
# Epoch 9/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4811 - binary_accuracy: 0.7674 - val_loss: 0.5251 - val_binary_accuracy: 0.7359
# Epoch 10/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4787 - binary_accuracy: 0.7688 - val_loss: 0.5067 - val_binary_accuracy: 0.7557
# Epoch 11/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4729 - binary_accuracy: 0.7720 - val_loss: 0.4670 - val_binary_accuracy: 0.7741
# Epoch 12/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4692 - binary_accuracy: 0.7737 - val_loss: 0.4865 - val_binary_accuracy: 0.7589
# Epoch 13/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4671 - binary_accuracy: 0.7779 - val_loss: 0.4643 - val_binary_accuracy: 0.7763
# Epoch 14/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4636 - binary_accuracy: 0.7767 - val_loss: 0.4792 - val_binary_accuracy: 0.7658
# Epoch 15/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4592 - binary_accuracy: 0.7808 - val_loss: 0.4726 - val_binary_accuracy: 0.7715
# Epoch 16/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4572 - binary_accuracy: 0.7819 - val_loss: 0.4563 - val_binary_accuracy: 0.7802
# Epoch 17/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4534 - binary_accuracy: 0.7848 - val_loss: 0.4597 - val_binary_accuracy: 0.7803
# Epoch 18/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4511 - binary_accuracy: 0.7854 - val_loss: 0.4646 - val_binary_accuracy: 0.7805
# Epoch 19/100
# 338/338 [==============================] - 10s 30ms/step - loss: 0.4485 - binary_accuracy: 0.7875 - val_loss: 0.4708 - val_binary_accuracy: 0.7734
# Epoch 20/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4430 - binary_accuracy: 0.7923 - val_loss: 0.4638 - val_binary_accuracy: 0.7784
# Epoch 21/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4418 - binary_accuracy: 0.7920 - val_loss: 0.4629 - val_binary_accuracy: 0.7796
# Epoch 22/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4411 - binary_accuracy: 0.7906 - val_loss: 0.4902 - val_binary_accuracy: 0.7617
# Epoch 23/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4370 - binary_accuracy: 0.7943 - val_loss: 0.4653 - val_binary_accuracy: 0.7756
# Epoch 24/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4353 - binary_accuracy: 0.7955 - val_loss: 0.4529 - val_binary_accuracy: 0.7831
# Epoch 25/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4318 - binary_accuracy: 0.7962 - val_loss: 0.4690 - val_binary_accuracy: 0.7749
# Epoch 26/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4313 - binary_accuracy: 0.7970 - val_loss: 0.4938 - val_binary_accuracy: 0.7718
# Epoch 27/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4285 - binary_accuracy: 0.7987 - val_loss: 0.4897 - val_binary_accuracy: 0.7676
# Epoch 28/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4259 - binary_accuracy: 0.7996 - val_loss: 0.4587 - val_binary_accuracy: 0.7838
# Epoch 29/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4279 - binary_accuracy: 0.8001 - val_loss: 0.4678 - val_binary_accuracy: 0.7759
# Epoch 30/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4233 - binary_accuracy: 0.8033 - val_loss: 0.4835 - val_binary_accuracy: 0.7739
# Epoch 31/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4249 - binary_accuracy: 0.8011 - val_loss: 0.4646 - val_binary_accuracy: 0.7826
# Epoch 32/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4193 - binary_accuracy: 0.8046 - val_loss: 0.4653 - val_binary_accuracy: 0.7830
# Epoch 33/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4148 - binary_accuracy: 0.8091 - val_loss: 0.4715 - val_binary_accuracy: 0.7767
# Epoch 34/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4143 - binary_accuracy: 0.8076 - val_loss: 0.4835 - val_binary_accuracy: 0.7751
# Epoch 35/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.4122 - binary_accuracy: 0.8093 - val_loss: 0.4718 - val_binary_accuracy: 0.7840
# Epoch 36/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4093 - binary_accuracy: 0.8109 - val_loss: 0.4660 - val_binary_accuracy: 0.7811
# Epoch 37/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4101 - binary_accuracy: 0.8101 - val_loss: 0.5161 - val_binary_accuracy: 0.7550
# Epoch 38/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4091 - binary_accuracy: 0.8101 - val_loss: 0.4658 - val_binary_accuracy: 0.7842
# Epoch 39/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4074 - binary_accuracy: 0.8132 - val_loss: 0.4647 - val_binary_accuracy: 0.7836
# Epoch 40/100
# 338/338 [==============================] - 10s 31ms/step - loss: 0.4058 - binary_accuracy: 0.8123 - val_loss: 0.5047 - val_binary_accuracy: 0.7644
# Epoch 41/100
# 338/338 [==============================] - 11s 33ms/step - loss: 0.4045 - binary_accuracy: 0.8144 - val_loss: 0.4779 - val_binary_accuracy: 0.7772
# Epoch 42/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4011 - binary_accuracy: 0.8156 - val_loss: 0.4823 - val_binary_accuracy: 0.7732
# Epoch 43/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.4005 - binary_accuracy: 0.8158 - val_loss: 0.5063 - val_binary_accuracy: 0.7724
# Epoch 44/100
# 338/338 [==============================] - 11s 32ms/step - loss: 0.3991 - binary_accuracy: 0.8171 - val_loss: 0.4845 - val_binary_accuracy: 0.7774
# Epoch 45/100
# 338/338 [==============================] - 11s 31ms/step - loss: 0.3957 - binary_accuracy: 0.8187 - val_loss: 0.4951 - val_binary_accuracy: 0.7766
# Training Accuracy: 0.834
# Validation Accuracy: 0.784

# %% [markdown]
# ##### RNN:

# %%
# Define the model
def create_model():
  model = Sequential()
  model.add(Embedding(max_features, embedding_dim, embeddings_initializer=Constant(embedding_matrix), input_length=max_len, trainable=False))
  model.add(GRU(256, kernel_initializer=GlorotUniform(seed=seed_value), dropout=0.5, recurrent_dropout=0.5))
  model.add(Dropout(rate=0.5, seed=seed_value))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
# Compile the model
with strategy.scope():
    model = create_model()
    model.compile(optimizer=Nadam(clipnorm=1.0), loss="binary_crossentropy", metrics=["binary_accuracy"], steps_per_execution=338)

# %%
# Show summary of the model
model.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_27 (Embedding)     (None, 1000, 300)         30000000
# _________________________________________________________________
# gru_13 (GRU)                 (None, 256)               428544
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 30,428,801
# Trainable params: 428,801
# Non-trainable params: 30,000,000
# _________________________________________________________________

# %%
# Train the model
model.fit(X_subtrain, y_subtrain, validation_data=(X_val, y_val), batch_size=512, epochs=100, verbose=1, shuffle=True, callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", patience=7, mode="max", restore_best_weights=True)])
print("Training Accuracy: {:.3f}".format(model.evaluate(X_subtrain, y_subtrain, batch_size=512, verbose=0)[1]))
print("Validation Accuracy: {:.3f}".format(model.evaluate(X_val, y_val, batch_size=512, verbose=0)[1]))
# Out:
# Epoch 1/100
# 338/338 [==============================] - 53s 158ms/step - loss: 0.6043 - binary_accuracy: 0.6685 - val_loss: 0.5945 - val_binary_accuracy: 0.7197
# Epoch 2/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5357 - binary_accuracy: 0.7252 - val_loss: 0.5485 - val_binary_accuracy: 0.7012
# Epoch 3/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5140 - binary_accuracy: 0.7410 - val_loss: 0.4971 - val_binary_accuracy: 0.7525
# Epoch 4/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.5012 - binary_accuracy: 0.7504 - val_loss: 0.4822 - val_binary_accuracy: 0.7632
# Epoch 5/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4918 - binary_accuracy: 0.7581 - val_loss: 0.4770 - val_binary_accuracy: 0.7674
# Epoch 6/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4819 - binary_accuracy: 0.7651 - val_loss: 0.4719 - val_binary_accuracy: 0.7719
# Epoch 7/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4759 - binary_accuracy: 0.7686 - val_loss: 0.4737 - val_binary_accuracy: 0.7693
# Epoch 8/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4698 - binary_accuracy: 0.7730 - val_loss: 0.4612 - val_binary_accuracy: 0.7780
# Epoch 9/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4644 - binary_accuracy: 0.7770 - val_loss: 0.4844 - val_binary_accuracy: 0.7621
# Epoch 10/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4596 - binary_accuracy: 0.7788 - val_loss: 0.4637 - val_binary_accuracy: 0.7790
# Epoch 11/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4558 - binary_accuracy: 0.7814 - val_loss: 0.4538 - val_binary_accuracy: 0.7830
# Epoch 12/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4512 - binary_accuracy: 0.7850 - val_loss: 0.4578 - val_binary_accuracy: 0.7790
# Epoch 13/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4481 - binary_accuracy: 0.7864 - val_loss: 0.4543 - val_binary_accuracy: 0.7811
# Epoch 14/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4446 - binary_accuracy: 0.7891 - val_loss: 0.4572 - val_binary_accuracy: 0.7809
# Epoch 15/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4422 - binary_accuracy: 0.7907 - val_loss: 0.4476 - val_binary_accuracy: 0.7868
# Epoch 16/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4386 - binary_accuracy: 0.7931 - val_loss: 0.4443 - val_binary_accuracy: 0.7869
# Epoch 17/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4352 - binary_accuracy: 0.7949 - val_loss: 0.4488 - val_binary_accuracy: 0.7861
# Epoch 18/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4336 - binary_accuracy: 0.7958 - val_loss: 0.4480 - val_binary_accuracy: 0.7882
# Epoch 19/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4299 - binary_accuracy: 0.7980 - val_loss: 0.4471 - val_binary_accuracy: 0.7869
# Epoch 20/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4275 - binary_accuracy: 0.7999 - val_loss: 0.4565 - val_binary_accuracy: 0.7817
# Epoch 21/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4260 - binary_accuracy: 0.8007 - val_loss: 0.4444 - val_binary_accuracy: 0.7888
# Epoch 22/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4233 - binary_accuracy: 0.8023 - val_loss: 0.4558 - val_binary_accuracy: 0.7854
# Epoch 23/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4218 - binary_accuracy: 0.8032 - val_loss: 0.4428 - val_binary_accuracy: 0.7888
# Epoch 24/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4194 - binary_accuracy: 0.8047 - val_loss: 0.4479 - val_binary_accuracy: 0.7863
# Epoch 25/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4184 - binary_accuracy: 0.8050 - val_loss: 0.4755 - val_binary_accuracy: 0.7717
# Epoch 26/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4164 - binary_accuracy: 0.8058 - val_loss: 0.4512 - val_binary_accuracy: 0.7885
# Epoch 27/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4151 - binary_accuracy: 0.8065 - val_loss: 0.4478 - val_binary_accuracy: 0.7863
# Epoch 28/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4121 - binary_accuracy: 0.8094 - val_loss: 0.4497 - val_binary_accuracy: 0.7884
# Epoch 29/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4119 - binary_accuracy: 0.8085 - val_loss: 0.4516 - val_binary_accuracy: 0.7840
# Epoch 30/100
# 338/338 [==============================] - 36s 105ms/step - loss: 0.4104 - binary_accuracy: 0.8099 - val_loss: 0.4531 - val_binary_accuracy: 0.7836
# Training Accuracy: 0.820
# Validation Accuracy: 0.789

# %% [markdown]
# ##### Results:

# %% [markdown]
# - FastText 300d: CNN = 79.8% vs. 78.3%; RNN = 81.9% vs. 78.9%
# - Glove Twitter 200d: 82.1% vs. 78.2%; RNN = 82% vs. 78.9%
# - Glove Wikipedia + Gigaword 300d: CNN = 80.8% vs. 78.3%; RNN = 80.3% vs. 78.4%
# - Word2Vec Google News 300d: CNN = 83.4% vs. 78.4%; RNN = 82% vs. 78.9%
# - i.e. different embeddings did not make a huge difference
# - i.e. stick to FastText, as it provided the best trade-off between good accuracy and low overfitting

# %% [markdown]
# #### f) Best-Found Model: NN Text

# %% [markdown]
# - Preprocessing: Stopwords Removed; All Text Attributes; No max_features restrictions; max_len=1000; embedding dimension = 300; Fasttext
# - CNN: 4 Conv Layer (64 Filter, Window Size 5, ReLU, padding=same); AveragePooling (Size 2); Gaussian Noise; Layer Normalization; Dropout (Rate=0.5); 1 Dense Layer (32 Units)
# - RNN: 1 GRU Layer (256 Units); Input/Output/Recurrent Dropout (Rate=0.5)
# - Optimization: GlorotUniform; Nadam; clipnorm=1.0; Batch Size: 512
