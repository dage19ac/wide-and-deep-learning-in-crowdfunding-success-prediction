# %% [markdown]
# #### Setup:

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### 1) Consolidate 2020 Files

# %%
# November
kickstarter_df = pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-11/Kickstarter.csv")
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-11/Kickstarter00{}.csv".format(i)))
for i in range(10,58):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-11/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (213193, 38)
# After: (188984, 38)
# 41420799      1
# 1542145218    1
# 2066429132    1
# 240648386     1
# 378145709     1
#              ..
# 1768274613    1
# 78590643      1
# 1866672816    1
# 585620142     1
# 2022774194    1
# Name: id, Length: 188984, dtype: int64

# %%
# October
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-10/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-10/Kickstarter00{}.csv".format(i)))
for i in range(10,60):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-10/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (408522, 38)
# After: (196205, 38)
# 41420799      1
# 1600103518    1
# 2095693446    1
# 122315878     1
# 1528064488    1
#              ..
# 443506907     1
# 1707229853    1
# 1027242650    1
# 876745367     1
# 2022774194    1
# Name: id, Length: 196205, dtype: int64

# %%
# September
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-09/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-09/Kickstarter00{}.csv".format(i)))
for i in range(10,60):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-09/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (415893, 38)
# After: (198805, 38)
# 41420799      1
# 542630998     1
# 1295344273    1
# 1077283947    1
# 1718891808    1
#              ..
# 1866672816    1
# 585620142     1
# 417231614     1
# 371192491     1
# 2022774194    1
# Name: id, Length: 198805, dtype: int64

# %%
# August
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-08/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-08/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-08/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (406842, 38)
# After: (201183, 38)
# 41420799      1
# 2095693446    1
# 1528064488    1
# 1276802148    1
# 411192419     1
#              ..
# 614523593     1
# 92334792      1
# 1505268423    1
# 1970051782    1
# 2022774194    1
# Name: id, Length: 201183, dtype: int64

# %%
# July
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-07/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-07/Kickstarter00{}.csv".format(i)))
for i in range(10,59):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-07/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (417696, 38)
# After: (203890, 38)
# 41420799      1
# 1994660069    1
# 819400119     1
# 618071478     1
# 358028724     1
#              ..
# 540884748     1
# 1205143307    1
# 248846089     1
# 1701668615    1
# 1329596417    1
# Name: id, Length: 203890, dtype: int64

# %%
# June
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-06/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-06/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-06/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (413335, 41)
# After: (206079, 41)
# 41420799      1
# 86568267      1
# 280614252     1
# 1706163561    1
# 1084689607    1
#              ..
# 712144613     1
# 1972535012    1
# 548554467     1
# 1451384544    1
# 1329596417    1
# Name: id, Length: 206079, dtype: int64

# %%
# May
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-05/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-05/Kickstarter00{}.csv".format(i)))
for i in range(10,59):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-05/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (423512, 41)
# After: (208796, 41)
# 41420799      1
# 944932102     1
# 290092312     1
# 1550454039    1
# 986322196     1
#              ..
# 964821694     1
# 666783330     1
# 1727329894    1
# 342865501     1
# 1329596417    1
# Name: id, Length: 208796, dtype: int64

# %%
# April
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-04/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-04/Kickstarter00{}.csv".format(i)))
for i in range(10,56):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-04/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (413421, 41)
# After: (210690, 41)
# 41420799      1
# 1040993503    1
# 231038205     1
# 1398109432    1
# 1256000759    1
#              ..
# 257726009     1
# 1903563880    1
# 2122120756    1
# 1388990259    1
# 1329596417    1
# Name: id, Length: 210690, dtype: int64

# %%
# March
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-03/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-03/Kickstarter00{}.csv".format(i)))
for i in range(10,59):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-03/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (426667, 41)
# After: (212761, 41)
# 41420799      1
# 1352404183    1
# 1719055235    1
# 1267236975    1
# 2001892085    1
#              ..
# 471596500     1
# 1353958867    1
# 1524283613    1
# 293283279     1
# 1329596417    1
# Name: id, Length: 212761, dtype: int64

# %%
# February
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-02/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-02/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-02/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (423837, 41)
# After: (216067, 41)
# 41420799      1
# 1266136224    1
# 1395590633    1
# 772724094     1
# 1581016282    1
#              ..
# 168893832     1
# 1511959934    1
# 587119996     1
# 699303291     1
# 1329596417    1
# Name: id, Length: 216067, dtype: int64

# %%
# January
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-01/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-01/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2020-01/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (427338, 41)
# After: (218777, 41)
# 41420799      1
# 1907457145    1
# 1499006070    1
# 385422452     1
# 1506880627    1
#              ..
# 1811023083    1
# 1228567781    1
# 602576705     1
# 1966232801    1
# 1329596417    1
# Name: id, Length: 218777, dtype: int64

# %% [markdown]
# #### 2) Consolidate 2019 Files

# %%
# Dezember
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-12/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-12/Kickstarter00{}.csv".format(i)))
for i in range(10,58):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-12/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (434577, 41)
# After: (220800, 41)
# 41420799      1
# 807398571     1
# 1935146153    1
# 667116317     1
# 607108257     1
#              ..
# 62579959      1
# 1834628286    1
# 771935474     1
# 1390599408    1
# 1329596417    1
# Name: id, Length: 220800, dtype: int64

# %%
# November
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-11/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-11/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-11/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (432224, 41)
# After: (222952, 41)
# 41420799      1
# 1726360590    1
# 415900690     1
# 1828379661    1
# 439912186     1
#              ..
# 836297911     1
# 1958272176    1
# 1668295854    1
# 135281836     1
# 1329596417    1
# Name: id, Length: 222952, dtype: int64

# %%
# October
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-10/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-10/Kickstarter00{}.csv".format(i)))
for i in range(10,56):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-10/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (428179, 41)
# After: (225568, 41)
# 41420799      1
# 1668426182    1
# 1864231915    1
# 38741312      1
# 739945941     1
#              ..
# 101088356     1
# 1090744948    1
# 1896762466    1
# 567694433     1
# 1329596417    1
# Name: id, Length: 225568, dtype: int64

# %%
# September
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-09/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-09/Kickstarter00{}.csv".format(i)))
for i in range(10,58):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-09/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (439225, 41)
# After: (228873, 41)
# 41420799      1
# 1804970979    1
# 1726360590    1
# 140889071     1
# 1107426852    1
#              ..
# 875355184     1
# 1340453       1
# 1354517538    1
# 1393843232    1
# 1329596417    1
# Name: id, Length: 228873, dtype: int64

# %%
# August
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-08/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-08/Kickstarter00{}.csv".format(i)))
for i in range(10,56):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-08/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (436494, 41)
# After: (231331, 41)
# 41420799      1
# 1828379661    1
# 1216136142    1
# 111144563     1
# 1611463625    1
#              ..
# 1302781627    1
# 979592135     1
# 1295205315    1
# 4440674       1
# 1329596417    1
# Name: id, Length: 231331, dtype: int64

# %%
# July
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-07/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-07/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-07/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (443709, 41)
# After: (233690, 41)
# 41420799      1
# 191547497     1
# 717200293     1
# 1379287966    1
# 557734813     1
#              ..
# 244886462     1
# 1929425853    1
# 939037625     1
# 157346742     1
# 1329596417    1
# Name: id, Length: 233690, dtype: int64

# %%
# June
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-06/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-06/Kickstarter00{}.csv".format(i)))
for i in range(10,57):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-06/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (445264, 41)
# After: (236501, 41)
# 41420799      1
# 82545447      1
# 2128327456    1
# 1530523740    1
# 13265691      1
#              ..
# 1058554787    1
# 1019759522    1
# 452773170     1
# 341418911     1
# 1329596417    1
# Name: id, Length: 236501, dtype: int64

# %%
# May
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-05/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-05/Kickstarter00{}.csv".format(i)))
for i in range(10,56):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-05/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (447358, 41)
# After: (239095, 41)
# 41420799      1
# 1841795748    1
# 391598780     1
# 2100232886    1
# 722934453     1
#              ..
# 1678734149    1
# 590838596     1
# 631718723     1
# 1920248638    1
# 1329596417    1
# Name: id, Length: 239095, dtype: int64

# %%
# April
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-04/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-04/Kickstarter00{}.csv".format(i)))
for i in range(10,56):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-04/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (449183, 41)
# After: (241769, 41)
# 41420799      1
# 1759597180    1
# 1551258268    1
# 1026980505    1
# 1984823958    1
#              ..
# 5663590       1
# 250508133     1
# 1182046948    1
# 1873697632    1
# 1329596417    1
# Name: id, Length: 241769, dtype: int64

# %%
# March
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-03/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-03/Kickstarter00{}.csv".format(i)))
for i in range(10,56):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-03/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (450991, 41)
# After: (244859, 41)
# 41420799      1
# 453164952     1
# 402500323     1
# 1437615914    1
# 1834762974    1
#              ..
# 634143523     1
# 2005682978    1
# 84693793      1
# 1048785879    1
# 1329596417    1
# Name: id, Length: 244859, dtype: int64

# %%
# February
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-02/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-02/Kickstarter00{}.csv".format(i)))
for i in range(10,55):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-02/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (453333, 41)
# After: (247558, 41)
# 41420799      1
# 593454551     1
# 902222476     1
# 1803477642    1
# 1375138440    1
#              ..
# 1954630274    1
# 886657665     1
# 873477528     1
# 1264497277    1
# 1329596417    1
# Name: id, Length: 247558, dtype: int64

# %%
# January
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-01/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-01/Kickstarter00{}.csv".format(i)))
for i in range(10,55):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2019-01/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (455406, 41)
# After: (249953, 41)
# 41420799      1
# 19723671      1
# 1026980505    1
# 1984823958    1
# 1346775699    1
#              ..
# 1158027880    1
# 608070246     1
# 1627814500    1
# 878592611     1
# 1329596417    1
# Name: id, Length: 249953, dtype: int64

# %% [markdown]
# #### 3) Consolidate 2018 Files

# %%
# Dezember
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-12/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-12/Kickstarter00{}.csv".format(i)))
for i in range(10,55):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-12/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (457180, 41)
# After: (290653, 41)
# 41420799      1
# 822320389     1
# 1371058499    1
# 81824068      1
# 1325912771    1
#              ..
# 708906123     1
# 84483209      1
# 974575896     1
# 1687256197    1
# 1329596417    1
# Name: id, Length: 290653, dtype: int64

# %%
# November
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-11/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-11/Kickstarter00{}.csv".format(i)))
for i in range(10,55):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-11/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (497195, 41)
# After: (291638, 41)
# 41420799      1
# 715957278     1
# 713221708     1
# 1501368567    1
# 1382373630    1
#              ..
# 436302980     1
# 1279870082    1
# 615603329     1
# 852403326     1
# 1329596417    1
# Name: id, Length: 291638, dtype: int64

# %%
# October
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-10/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-10/Kickstarter00{}.csv".format(i)))
for i in range(10,54):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-10/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (497334, 41)
# After: (292637, 41)
# 41420799      1
# 1104818399    1
# 117776208     1
# 598165692     1
# 1060585661    1
#              ..
# 2048803938    1
# 1338399841    1
# 1600103518    1
# 1236253789    1
# 1329596417    1
# Name: id, Length: 292637, dtype: int64

# %%
# September
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-09/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-09/Kickstarter00{}.csv".format(i)))
for i in range(10,51):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-09/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (497728, 41)
# After: (293955, 41)
# 41420799      1
# 196253958     1
# 1501368567    1
# 1382373630    1
# 1717217536    1
#              ..
# 26570553      1
# 2095693446    1
# 1528064488    1
# 2036436226    1
# 1329596417    1
# Name: id, Length: 293955, dtype: int64

# %%
# August
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-08/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-08/Kickstarter00{}.csv".format(i)))
for i in range(10,50):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-08/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (497840, 41)
# After: (295128, 41)
# 41420799      1
# 156455206     1
# 1055146205    1
# 1296324830    1
# 433957088     1
#              ..
# 914947656     1
# 474604490     1
# 1009366663    1
# 823575666     1
# 1329596417    1
# Name: id, Length: 295128, dtype: int64

# %%
# July
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-07/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-07/Kickstarter00{}.csv".format(i)))
for i in range(10,50):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-07/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (498016, 41)
# After: (296397, 41)
# 41420799      1
# 317745496     1
# 853493513     1
# 1717217536    1
# 1481810177    1
#              ..
# 1294589073    1
# 2065810578    1
# 145345683     1
# 821163156     1
# 1329596417    1
# Name: id, Length: 296397, dtype: int64

# %%
# June
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-06/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-06/Kickstarter00{}.csv".format(i)))
for i in range(10,50):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-06/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (498425, 41)
# After: (297796, 41)
# 41420799      1
# 1453189352    1
# 1602718231    1
# 1124217107    1
# 335677716     1
#              ..
# 379184278     1
# 1760685207    1
# 145008707     1
# 642358425     1
# 1329596417    1
# Name: id, Length: 297796, dtype: int64

# %%
# May
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-05/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-05/Kickstarter00{}.csv".format(i)))
for i in range(10,50):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-05/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (499907, 41)
# After: (299399, 41)
# 41420799      1
# 1701618547    1
# 1469292833    1
# 881170241     1
# 279163171     1
#              ..
# 1542145218    1
# 638282951     1
# 1223890120    1
# 1654326474    1
# 1329596417    1
# Name: id, Length: 299399, dtype: int64

# %%
# April
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-04/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-04/Kickstarter00{}.csv".format(i)))
for i in range(10,49):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-04/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (499336, 41)
# After: (310300, 41)
# 41420799      1
# 1328216330    1
# 1040896271    1
# 1296588886    1
# 1602718231    1
#              ..
# 229656614     1
# 1294589073    1
# 2065810578    1
# 145345683     1
# 1329596417    1
# Name: id, Length: 310300, dtype: int64

# %%
# March
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-03/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-03/Kickstarter00{}.csv".format(i)))
for i in range(10,50):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-03/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (509268, 41)
# After: (311601, 41)
# 41420799      1
# 1812243504    1
# 1091289389    1
# 537123118     1
# 417059119     1
#              ..
# 2095693446    1
# 26570553      1
# 1238768745    1
# 1077283947    1
# 1329596417    1
# Name: id, Length: 311601, dtype: int64

# %%
# February
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-02/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-02/Kickstarter00{}.csv".format(i)))
for i in range(10,49):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-02/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (507215, 41)
# After: (312574, 41)
# 41420799      1
# 677151605     1
# 1220360434    1
# 713221708     1
# 1501368567    1
#              ..
# 1243556943    1
# 73631262      1
# 222807122     1
# 119534676     1
# 1329596417    1
# Name: id, Length: 312574, dtype: int64

# %%
# January
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-01/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-01/Kickstarter00{}.csv".format(i)))
for i in range(10,49):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2018-01/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (509366, 41)
# After: (313853, 41)
# 41420799      1
# 1887609542    1
# 1070070090    1
# 674009287     1
# 1366077895    1
#              ..
# 1798587426    1
# 742683684     1
# 649326477     1
# 2074071444    1
# 1329596417    1
# Name: id, Length: 313853, dtype: int64

# %% [markdown]
# #### 4) Consolidate 2017 Files

# %%
# Dezember
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-12/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-12/Kickstarter00{}.csv".format(i)))
for i in range(10,49):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-12/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (509796, 41)
# After: (314912, 41)
# 41420799      1
# 1060585661    1
# 520554676     1
# 1279645800    1
# 480616924     1
#              ..
# 317903856     1
# 1671375243    1
# 184738806     1
# 636132345     1
# 1329596417    1
# Name: id, Length: 314912, dtype: int64

# %%
# November
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-11/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-11/Kickstarter00{}.csv".format(i)))
for i in range(10,40):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-11/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (473086, 41)
# After: (315821, 41)
# 41420799      1
# 1387221183    1
# 1279645800    1
# 480616924     1
# 539977912     1
#              ..
# 861549548     1
# 317903856     1
# 1671375243    1
# 184738806     1
# 1329596417    1
# Name: id, Length: 315821, dtype: int64

# %%
# October
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-10/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-10/Kickstarter00{}.csv".format(i)))
for i in range(10,40):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-10/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (472948, 41)
# After: (316799, 41)
# 41420799      1
# 1366077895    1
# 1060585661    1
# 1387221183    1
# 1648142528    1
#              ..
# 841200604     1
# 65780701      1
# 1149477854    1
# 157527007     1
# 1329596417    1
# Name: id, Length: 316799, dtype: int64

# %%
# September
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-09/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-09/Kickstarter00{}.csv".format(i)))
for i in range(10,39):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-09/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (472765, 41)
# After: (317680, 41)
# 41420799      1
# 433957088     1
# 1575227607    1
# 1768451526    1
# 1526489305    1
#              ..
# 1389755413    1
# 198546456     1
# 1726905024    1
# 291341338     1
# 1329596417    1
# Name: id, Length: 317680, dtype: int64

# %%
# August
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-08/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-08/Kickstarter00{}.csv".format(i)))
for i in range(10,42):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-08/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (487512, 41)
# After: (327920, 41)
# 41420799      1
# 1549745278    1
# 357501885     1
# 15381058      1
# 658921930     1
#              ..
# 2099424255    1
# 1612082334    1
# 128809989     1
# 995451910     1
# 1329596417    1
# Name: id, Length: 327920, dtype: int64

# %%
# July
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-07/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-07/Kickstarter00{}.csv".format(i)))
for i in range(10,48):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-07/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (524677, 41)
# After: (352755, 41)
# 41420799      1
# 1296588886    1
# 1481810177    1
# 677151605     1
# 715957278     1
#              ..
# 393511994     1
# 1394904123    1
# 765768764     1
# 904182845     1
# 1329596417    1
# Name: id, Length: 352755, dtype: int64

# %%
# June
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-06/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-06/Kickstarter00{}.csv".format(i)))
for i in range(10,48):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-06/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (547573, 41)
# After: (353713, 41)
# 41420799      1
# 1585707306    1
# 399661342     1
# 2146641050    1
# 1469292833    1
#              ..
# 2007055151    1
# 1571234894    1
# 1243556943    1
# 73631262      1
# 1329596417    1
# Name: id, Length: 353713, dtype: int64

# %%
# May
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-05/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-05/Kickstarter00{}.csv".format(i)))
for i in range(10,45):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-05/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (535001, 41)
# After: (360939, 41)
# 41420799      1
# 407921241     1
# 713221708     1
# 1501368567    1
# 786778364     1
#              ..
# 73631262      1
# 222807122     1
# 119534676     1
# 784858197     1
# 1329596417    1
# Name: id, Length: 360939, dtype: int64

# %%
# April
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-04/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-04/Kickstarter00{}.csv".format(i)))
for i in range(10,44):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-04/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (540250, 41)
# After: (363263, 41)
# 41420799      1
# 715957278     1
# 1585707306    1
# 899936555     1
# 1091289389    1
#              ..
# 1243556943    1
# 73631262      1
# 222807122     1
# 119534676     1
# 1329596417    1
# Name: id, Length: 363263, dtype: int64

# %%
# March
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-03/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-03/Kickstarter00{}.csv".format(i)))
for i in range(10,44):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-03/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (540403, 41)
# After: (365838, 41)
# 41420799      1
# 636694835     1
# 815927575     1
# 197818650     1
# 1220702491    1
#              ..
# 1900346421    1
# 1413126       1
# 1503435833    1
# 393511994     1
# 1329596417    1
# Name: id, Length: 365838, dtype: int64

# %%
# February
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-02/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-02/Kickstarter00{}.csv".format(i)))
for i in range(10,43):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-02/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (540923, 41)
# After: (368186, 41)
# 41420799      1
# 853493513     1
# 433957088     1
# 1004998400    1
# 924168419     1
#              ..
# 1612082334    1
# 74269698      1
# 128809989     1
# 995451910     1
# 1329596417    1
# Name: id, Length: 368186, dtype: int64

# %%
# January
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-01/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-01/Kickstarter00{}.csv".format(i)))
for i in range(10,42):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2017-01/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (541078, 41)
# After: (368845, 41)
# 41420799      1
# 818274537     1
# 506327275     1
# 307807179     1
# 107331821     1
#              ..
# 1970462681    1
# 249904141     1
# 1240901943    1
# 1389755413    1
# 1329596417    1
# Name: id, Length: 368845, dtype: int64

# %% [markdown]
# #### 5) Consolidate 2016 Files

# %%
# Dezember
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-12/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-12/Kickstarter00{}.csv".format(i)))
for i in range(10,42):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-12/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (540226, 41)
# After: (369598, 41)
# 41420799      1
# 1575227607    1
# 1526489305    1
# 559184090     1
# 1140093147    1
#              ..
# 197996098     1
# 1511367710    1
# 552358944     1
# 1798587426    1
# 1329596417    1
# Name: id, Length: 369598, dtype: int64

# %%
# November
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-11/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-11/Kickstarter00{}.csv".format(i)))
for i in range(10,41):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-11/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (538790, 41)
# After: (370541, 41)
# 41420799      1
# 815532244     1
# 1768451526    1
# 1526489305    1
# 559184090     1
#              ..
# 1240901943    1
# 1389755413    1
# 198546456     1
# 1726905024    1
# 1329596417    1
# Name: id, Length: 370541, dtype: int64

# %%
# October
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-10/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-10/Kickstarter00{}.csv".format(i)))
for i in range(10,41):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-10/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (537845, 41)
# After: (371196, 41)
# 41420799      1
# 1948213433    1
# 598165692     1
# 1060585661    1
# 1387221183    1
#              ..
# 2080295399    1
# 1671375243    1
# 184738806     1
# 1838985720    1
# 1329596417    1
# Name: id, Length: 371196, dtype: int64

# %%
# September
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-09/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-09/Kickstarter00{}.csv".format(i)))
for i in range(10,40):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-09/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (536574, 41)
# After: (371795, 41)
# 41420799      1
# 815532244     1
# 1768451526    1
# 1526489305    1
# 559184090     1
#              ..
# 128809989     1
# 995451910     1
# 1598909447    1
# 1214017466    1
# 1329596417    1
# Name: id, Length: 371795, dtype: int64

# %%
# August
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-08/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-08/Kickstarter00{}.csv".format(i)))
for i in range(10,40):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-08/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (535168, 41)
# After: (372503, 41)
# 41420799      1
# 1060585661    1
# 1648142528    1
# 645177537     1
# 1104818399    1
#              ..
# 1067082726    1
# 176006061     1
# 894799930     1
# 62357321      1
# 1329596417    1
# Name: id, Length: 372503, dtype: int64

# %%
# July
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-07/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-07/Kickstarter00{}.csv".format(i)))
for i in range(10,39):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-07/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (533950, 41)
# After: (373139, 41)
# 41420799      1
# 1070070090    1
# 1366077895    1
# 1893529802    1
# 1478815947    1
#              ..
# 1732739285    1
# 317903856     1
# 2080295399    1
# 1671375243    1
# 1329596417    1
# Name: id, Length: 373139, dtype: int64

# %%
# June
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-06/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-06/Kickstarter00{}.csv".format(i)))
for i in range(10,39):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-06/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (532554, 41)
# After: (373808, 41)
# 41420799      1
# 1104818399    1
# 674009287     1
# 1366077895    1
# 1893529802    1
#              ..
# 998378475     1
# 861549548     1
# 1118000152    1
# 1732739285    1
# 1329596417    1
# Name: id, Length: 373808, dtype: int64

# %%
# May
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-05/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-05/Kickstarter00{}.csv".format(i)))
for i in range(10,33):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-05/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (519434, 41)
# After: (374562, 41)
# 41420799      1
# 1060585661    1
# 1648142528    1
# 645177537     1
# 1104818399    1
#              ..
# 157527007     1
# 1446789804    1
# 1343900643    1
# 1081527335    1
# 1329596417    1
# Name: id, Length: 374562, dtype: int64

# %%
# April
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-04/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-04/Kickstarter00{}.csv".format(i)))
for i in range(10,35):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-04/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (529067, 41)
# After: (375249, 41)
# 41420799      1
# 253743279     1
# 374217088     1
# 99192460      1
# 520554676     1
#              ..
# 1789129684    1
# 2043935701    1
# 2059133910    1
# 577750506     1
# 1329596417    1
# Name: id, Length: 375249, dtype: int64

# %%
# March
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-03/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-03/Kickstarter00{}.csv".format(i)))
for i in range(10,34):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-03/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (527704, 41)
# After: (375820, 41)
# 41420799      1
# 430047096     1
# 161874069     1
# 18317111      1
# 1034315928    1
#              ..
# 1109540798    1
# 1051943878    1
# 1520135111    1
# 1494946760    1
# 1329596417    1
# Name: id, Length: 375820, dtype: int64

# %%
# January
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-01/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-01/Kickstarter00{}.csv".format(i)))
for i in range(10,32):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2016-01/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (523249, 41)
# After: (376622, 41)
# 41420799      1
# 2128066722    1
# 566248063     1
# 207061157     1
# 1944031399    1
#              ..
# 1149477854    1
# 157527007     1
# 1446789804    1
# 1343900643    1
# 1329596417    1
# Name: id, Length: 376622, dtype: int64

# %% [markdown]
# #### 6) Consolidate 2015 Files

# %%
# December 2015
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2015-12/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2015-12/Kickstarter00{}.csv".format(i)))
for i in range(10,32):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2015-12/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (520885, 41)
# After: (377159, 41)
# 41420799      1
# 943945450     1
# 15381058      1
# 658921930     1
# 59746464      1
#              ..
# 1732739285    1
# 317903856     1
# 2080295399    1
# 1671375243    1
# 1329596417    1
# Name: id, Length: 377159, dtype: int64

# %%
# November 2015
kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2015-11/Kickstarter.csv"))
for i in range(1,10):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2015-11/Kickstarter00{}.csv".format(i)))
for i in range(10,13):
    kickstarter_df = kickstarter_df.append(pd.read_csv("01_Raw Data/Webrobots/Kickstarter_2015-11/Kickstarter0{}.csv".format(i)))

# %%
# Drop duplicate values
print("Before: {}".format(kickstarter_df.shape))
kickstarter_df.drop_duplicates(subset=["id"], keep="first", inplace=True)
print("After: {}".format(kickstarter_df.shape))
kickstarter_df.id.value_counts()
# Out:
# Before: (435168, 41)
# After: (387664, 41)
# 41420799      1
# 713221708     1
# 818274537     1
# 1500903658    1
# 506327275     1
#              ..
# 1856783770    1
# 524985342     1
# 2099424255    1
# 1612082334    1
# 1329596417    1
# Name: id, Length: 387664, dtype: int64

# %% [markdown]
# #### Save Dataset:

# %%
# Save File to CSV
kickstarter_df.to_csv("02_Data Collection/Kickstarter_Webrobots.csv")

# %%
kickstarter_df = pd.read_csv("02_Data Collection/Kickstarter_Webrobots.csv", index_col=0)
print(kickstarter_df.shape)
kickstarter_df.id.value_counts()
# Out:
# (387664, 41)
# 41420799      1
# 713221708     1
# 818274537     1
# 1500903658    1
# 506327275     1
#              ..
# 1856783770    1
# 524985342     1
# 2099424255    1
# 1612082334    1
# 1329596417    1
# Name: id, Length: 387664, dtype: int64
